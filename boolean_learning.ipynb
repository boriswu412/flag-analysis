# %%
from proof_protocol import *
from protocol import *
from flag_analysis import *
from circuit_op import *
start_node, protocol = load_protocol("protocols/origin_5_1_3_protocol.json")

config = read_config("[[5,1,3]]_origin/[[5,1,3]]_origin_config.txt")
gen = load_symplectic_txt(str(config['stab_txt_path']))

init_state = new_clean_circuit_state(len(gen[0][0]))
t = 1

path = proof_protocol_boolean(protocol, start_node, init_state, config ,t)
# Out:
# Current node: root Instruction: XZZXI
# round: 0 node: root instr: XZZXI
# index: 0 name: cx qidxs: [5, 0]
# index: 1 name: cx qidxs: [5, 6]
# index: 2 name: cz qidxs: [1, 5]
# index: 3 name: cz qidxs: [2, 5]
# index: 4 name: cx qidxs: [5, 6]
# index: 5 name: cx qidxs: [5, 3]
# Current node: XZZXI_s_f_all_zero Instruction: IXZZX
# round: 1 node: XZZXI_s_f_all_zero instr: IXZZX
# index: 0 name: cx qidxs: [5, 1]
# index: 1 name: cx qidxs: [5, 6]
# index: 2 name: cz qidxs: [2, 5]
# index: 3 name: cz qidxs: [3, 5]
# index: 4 name: cx qidxs: [5, 6]
# index: 5 name: cx qidxs: [5, 4]
# Current node: IXZZX_s_f_all_zero Instruction: XIXZZ
# round: 2 node: IXZZX_s_f_all_zero instr: XIXZZ
# index: 0 name: cx qidxs: [5, 0]
# index: 1 name: cx qidxs: [5, 6]
# index: 2 name: cz qidxs: [3, 5]
# index: 3 name: cz qidxs: [4, 5]
# index: 4 name: cx qidxs: [5, 6]
# index: 5 name: cx qidxs: [5, 2]
# Current node: XIXZZ_s_f_all_zero Instruction: ZXIXZ
# round: 3 node: XIXZZ_s_f_all_zero instr: ZXIXZ
# index: 0 name: cx qidxs: [5, 1]
# index: 1 name: cx qidxs: [5, 6]
# index: 2 name: cz qidxs: [0, 5]
# index: 3 name: cz qidxs: [4, 5]
# index: 4 name: cx qidxs: [5, 6]
# index: 5 name: cx qidxs: [5, 3]
# Current node: ZXIXZ_s_f_all_zero Instruction: None
# Current node: ter_5 Instruction: Break
# Current node: ZXIXZ_s_f_not_all_zero Instruction: raw_syndrome
# round: 4 node: ZXIXZ_s_f_not_all_zero instr: raw_syndrome
# index: 0 name: cx qidxs: [5, 0]
# index: 1 name: cz qidxs: [1, 5]
# index: 2 name: cz qidxs: [2, 5]
# index: 3 name: cx qidxs: [5, 3]
# index: 4 name: cx qidxs: [6, 1]
# index: 5 name: cz qidxs: [2, 6]
# index: 6 name: cz qidxs: [3, 6]
# index: 7 name: cx qidxs: [6, 4]
# index: 8 name: cx qidxs: [7, 0]
# index: 9 name: cz qidxs: [3, 7]
# index: 10 name: cz qidxs: [4, 7]
# index: 11 name: cx qidxs: [7, 2]
# index: 12 name: cx qidxs: [8, 1]
# index: 13 name: cz qidxs: [0, 8]
# index: 14 name: cz qidxs: [4, 8]
# index: 15 name: cx qidxs: [8, 3]
# Current node: ter_4 Instruction: LUT_s_0_f_0_s_4_s_1_f_1_s_4_s_2_f_2_s_4_s_3_f_3_s_4
# LUT LUT_s_0_f_0_s_4_s_1_f_1_s_4_s_2_f_2_s_4_s_3_f_3_s_4
# gen_syn: [('s', 0), ('f', 0), ('s', 4), ('s', 1), ('f', 1), ('s', 4), ('s', 2), ('f', 2), ('s', 4), ('s', 3), ('f', 3), ('s', 4)]
# len all paths: 2
# Path 2 data collected:
#   - Last data qubits: 5 qubits
#   - Rounds with anc/flag: 6
#   - Path conditions: 6
# Current node: XIXZZ_s_f_not_all_zero Instruction: raw_syndrome
# round: 3 node: XIXZZ_s_f_not_all_zero instr: raw_syndrome
# index: 0 name: cx qidxs: [5, 0]
# index: 1 name: cz qidxs: [1, 5]
# index: 2 name: cz qidxs: [2, 5]
# index: 3 name: cx qidxs: [5, 3]
# index: 4 name: cx qidxs: [6, 1]
# index: 5 name: cz qidxs: [2, 6]
# index: 6 name: cz qidxs: [3, 6]
# index: 7 name: cx qidxs: [6, 4]
# index: 8 name: cx qidxs: [7, 0]
# index: 9 name: cz qidxs: [3, 7]
# index: 10 name: cz qidxs: [4, 7]
# index: 11 name: cx qidxs: [7, 2]
# index: 12 name: cx qidxs: [8, 1]
# index: 13 name: cz qidxs: [0, 8]
# index: 14 name: cz qidxs: [4, 8]
# index: 15 name: cx qidxs: [8, 3]
# Current node: ter_3 Instruction: LUT_s_0_f_0_s_3_s_1_f_1_s_3_s_2_f_2_s_3
# LUT LUT_s_0_f_0_s_3_s_1_f_1_s_3_s_2_f_2_s_3
# gen_syn: [('s', 0), ('f', 0), ('s', 3), ('s', 1), ('f', 1), ('s', 3), ('s', 2), ('f', 2), ('s', 3)]
# len all paths: 3
# Path 3 data collected:
#   - Last data qubits: 5 qubits
#   - Rounds with anc/flag: 5
#   - Path conditions: 5
# Current node: IXZZX_s_f_not_all_zero Instruction: raw_syndrome
# round: 2 node: IXZZX_s_f_not_all_zero instr: raw_syndrome
# index: 0 name: cx qidxs: [5, 0]
# index: 1 name: cz qidxs: [1, 5]
# index: 2 name: cz qidxs: [2, 5]
# index: 3 name: cx qidxs: [5, 3]
# index: 4 name: cx qidxs: [6, 1]
# index: 5 name: cz qidxs: [2, 6]
# index: 6 name: cz qidxs: [3, 6]
# index: 7 name: cx qidxs: [6, 4]
# index: 8 name: cx qidxs: [7, 0]
# index: 9 name: cz qidxs: [3, 7]
# index: 10 name: cz qidxs: [4, 7]
# index: 11 name: cx qidxs: [7, 2]
# index: 12 name: cx qidxs: [8, 1]
# index: 13 name: cz qidxs: [0, 8]
# index: 14 name: cz qidxs: [4, 8]
# index: 15 name: cx qidxs: [8, 3]
# Current node: ter_2 Instruction: LUT_s_0_f_0_s_2_s_1_f_1_s_2
# LUT LUT_s_0_f_0_s_2_s_1_f_1_s_2
# gen_syn: [('s', 0), ('f', 0), ('s', 2), ('s', 1), ('f', 1), ('s', 2)]
# len all paths: 4
# Path 4 data collected:
#   - Last data qubits: 5 qubits
#   - Rounds with anc/flag: 4
#   - Path conditions: 4
# Current node: XZZXI_s_f_not_all_zero Instruction: raw_syndrome
# round: 1 node: XZZXI_s_f_not_all_zero instr: raw_syndrome
# index: 0 name: cx qidxs: [5, 0]
# index: 1 name: cz qidxs: [1, 5]
# index: 2 name: cz qidxs: [2, 5]
# index: 3 name: cx qidxs: [5, 3]
# index: 4 name: cx qidxs: [6, 1]
# index: 5 name: cz qidxs: [2, 6]
# index: 6 name: cz qidxs: [3, 6]
# index: 7 name: cx qidxs: [6, 4]
# index: 8 name: cx qidxs: [7, 0]
# index: 9 name: cz qidxs: [3, 7]
# index: 10 name: cz qidxs: [4, 7]
# index: 11 name: cx qidxs: [7, 2]
# index: 12 name: cx qidxs: [8, 1]
# index: 13 name: cz qidxs: [0, 8]
# index: 14 name: cz qidxs: [4, 8]
# index: 15 name: cx qidxs: [8, 3]
# Current node: ter_1 Instruction: LUT_s_0_f_0_s_1
# LUT LUT_s_0_f_0_s_1
# gen_syn: [('s', 0), ('f', 0), ('s', 1)]
# len all paths: 5
# Path 5 data collected:
#   - Last data qubits: 5 qubits
#   - Rounds with anc/flag: 3
#   - Path conditions: 3
#
# ================================================================================
# COLLECTED DATA FROM 5 PATHS
# ================================================================================
#
# --- PATH 1 ---
#
# Measured syndrome:
#    None
#
# Commutation syndrome:
#    None
#
# Syndrome equality constraint:
#    None
#
# 0. Fault variables (count = 24):
#    f[0]: Or(Or(r_0_faulty_gate0_x0, r_0_faulty_gate0_z0),
#    Or(r_0_faulty_gate0_x1, r_0_faulty_gate0_z1))
#    f[1]: Or(Or(r_0_faulty_gate1_x0, r_0_faulty_gate1_z0),
#    Or(r_0_faulty_gate1_x1, r_0_faulty_gate1_z1))
#    f[2]: Or(Or(r_0_faulty_gate2_x0, r_0_faulty_gate2_z0),
#    Or(r_0_faulty_gate2_x1, r_0_faulty_gate2_z1))
#    f[3]: Or(Or(r_0_faulty_gate3_x0, r_0_faulty_gate3_z0),
#    Or(r_0_faulty_gate3_x1, r_0_faulty_gate3_z1))
#    f[4]: Or(Or(r_0_faulty_gate4_x0, r_0_faulty_gate4_z0),
#    Or(r_0_faulty_gate4_x1, r_0_faulty_gate4_z1))
#    f[5]: Or(Or(r_0_faulty_gate5_x0, r_0_faulty_gate5_z0),
#    Or(r_0_faulty_gate5_x1, r_0_faulty_gate5_z1))
#    f[6]: Or(Or(r_1_faulty_gate0_x0, r_1_faulty_gate0_z0),
#    Or(r_1_faulty_gate0_x1, r_1_faulty_gate0_z1))
#    f[7]: Or(Or(r_1_faulty_gate1_x0, r_1_faulty_gate1_z0),
#    Or(r_1_faulty_gate1_x1, r_1_faulty_gate1_z1))
#    f[8]: Or(Or(r_1_faulty_gate2_x0, r_1_faulty_gate2_z0),
#    Or(r_1_faulty_gate2_x1, r_1_faulty_gate2_z1))
#    f[9]: Or(Or(r_1_faulty_gate3_x0, r_1_faulty_gate3_z0),
#    Or(r_1_faulty_gate3_x1, r_1_faulty_gate3_z1))
#    f[10]: Or(Or(r_1_faulty_gate4_x0, r_1_faulty_gate4_z0),
#    Or(r_1_faulty_gate4_x1, r_1_faulty_gate4_z1))
#    f[11]: Or(Or(r_1_faulty_gate5_x0, r_1_faulty_gate5_z0),
#    Or(r_1_faulty_gate5_x1, r_1_faulty_gate5_z1))
#    f[12]: Or(Or(r_2_faulty_gate0_x0, r_2_faulty_gate0_z0),
#    Or(r_2_faulty_gate0_x1, r_2_faulty_gate0_z1))
#    f[13]: Or(Or(r_2_faulty_gate1_x0, r_2_faulty_gate1_z0),
#    Or(r_2_faulty_gate1_x1, r_2_faulty_gate1_z1))
#    f[14]: Or(Or(r_2_faulty_gate2_x0, r_2_faulty_gate2_z0),
#    Or(r_2_faulty_gate2_x1, r_2_faulty_gate2_z1))
#    f[15]: Or(Or(r_2_faulty_gate3_x0, r_2_faulty_gate3_z0),
#    Or(r_2_faulty_gate3_x1, r_2_faulty_gate3_z1))
#    f[16]: Or(Or(r_2_faulty_gate4_x0, r_2_faulty_gate4_z0),
#    Or(r_2_faulty_gate4_x1, r_2_faulty_gate4_z1))
#    f[17]: Or(Or(r_2_faulty_gate5_x0, r_2_faulty_gate5_z0),
#    Or(r_2_faulty_gate5_x1, r_2_faulty_gate5_z1))
#    f[18]: Or(Or(r_3_faulty_gate0_x0, r_3_faulty_gate0_z0),
#    Or(r_3_faulty_gate0_x1, r_3_faulty_gate0_z1))
#    f[19]: Or(Or(r_3_faulty_gate1_x0, r_3_faulty_gate1_z0),
#    Or(r_3_faulty_gate1_x1, r_3_faulty_gate1_z1))
#    f[20]: Or(Or(r_3_faulty_gate2_x0, r_3_faulty_gate2_z0),
#    Or(r_3_faulty_gate2_x1, r_3_faulty_gate2_z1))
#    f[21]: Or(Or(r_3_faulty_gate3_x0, r_3_faulty_gate3_z0),
#    Or(r_3_faulty_gate3_x1, r_3_faulty_gate3_z1))
#    f[22]: Or(Or(r_3_faulty_gate4_x0, r_3_faulty_gate4_z0),
#    Or(r_3_faulty_gate4_x1, r_3_faulty_gate4_z1))
#    f[23]: Or(Or(r_3_faulty_gate5_x0, r_3_faulty_gate5_z0),
#    Or(r_3_faulty_gate5_x1, r_3_faulty_gate5_z1))
#
#    At-most-1-faults constraint (PbEq):
#    PbEq(((Or(Or(r_0_faulty_gate0_x0, r_0_faulty_gate0_z0),
#           Or(r_0_faulty_gate0_x1, r_0_faulty_gate0_z1)),
#        1),
#       (Or(Or(r_0_faulty_gate1_x0, r_0_faulty_gate1_z0),
#           Or(r_0_faulty_gate1_x1, r_0_faulty_gate1_z1)),
#        1),
#       (Or(Or(r_0_faulty_gate2_x0, r_0_faulty_gate2_z0),
#           Or(r_0_faulty_gate2_x1, r_0_faulty_gate2_z1)),
#        1),
#       (Or(Or(r_0_faulty_gate3_x0, r_0_faulty_gate3_z0),
#           Or(r_0_faulty_gate3_x1, r_0_faulty_gate3_z1)),
#        1),
#       (Or(Or(r_0_faulty_gate4_x0, r_0_faulty_gate4_z0),
#           Or(r_0_faulty_gate4_x1, r_0_faulty_gate4_z1)),
#        1),
#       (Or(Or(r_0_faulty_gate5_x0, r_0_faulty_gate5_z0),
#           Or(r_0_faulty_gate5_x1, r_0_faulty_gate5_z1)),
#        1),
#       (Or(Or(r_1_faulty_gate0_x0, r_1_faulty_gate0_z0),
#           Or(r_1_faulty_gate0_x1, r_1_faulty_gate0_z1)),
#        1),
#       (Or(Or(r_1_faulty_gate1_x0, r_1_faulty_gate1_z0),
#           Or(r_1_faulty_gate1_x1, r_1_faulty_gate1_z1)),
#        1),
#       (Or(Or(r_1_faulty_gate2_x0, r_1_faulty_gate2_z0),
#           Or(r_1_faulty_gate2_x1, r_1_faulty_gate2_z1)),
#        1),
#       (Or(Or(r_1_faulty_gate3_x0, r_1_faulty_gate3_z0),
#           Or(r_1_faulty_gate3_x1, r_1_faulty_gate3_z1)),
#        1),
#       (Or(Or(r_1_faulty_gate4_x0, r_1_faulty_gate4_z0),
#           Or(r_1_faulty_gate4_x1, r_1_faulty_gate4_z1)),
#        1),
#       (Or(Or(r_1_faulty_gate5_x0, r_1_faulty_gate5_z0),
#           Or(r_1_faulty_gate5_x1, r_1_faulty_gate5_z1)),
#        1),
#       (Or(Or(r_2_faulty_gate0_x0, r_2_faulty_gate0_z0),
#           Or(r_2_faulty_gate0_x1, r_2_faulty_gate0_z1)),
#        1),
#       (Or(Or(r_2_faulty_gate1_x0, r_2_faulty_gate1_z0),
#           Or(r_2_faulty_gate1_x1, r_2_faulty_gate1_z1)),
#        1),
#       (Or(Or(r_2_faulty_gate2_x0, r_2_faulty_gate2_z0),
#           Or(r_2_faulty_gate2_x1, r_2_faulty_gate2_z1)),
#        1),
#       (Or(Or(r_2_faulty_gate3_x0, r_2_faulty_gate3_z0),
#           Or(r_2_faulty_gate3_x1, r_2_faulty_gate3_z1)),
#        1),
#       (Or(Or(r_2_faulty_gate4_x0, r_2_faulty_gate4_z0),
#           Or(r_2_faulty_gate4_x1, r_2_faulty_gate4_z1)),
#        1),
#       (Or(Or(r_2_faulty_gate5_x0, r_2_faulty_gate5_z0),
#           Or(r_2_faulty_gate5_x1, r_2_faulty_gate5_z1)),
#        1),
#       (Or(Or(r_3_faulty_gate0_x0, r_3_faulty_gate0_z0),
#           Or(r_3_faulty_gate0_x1, r_3_faulty_gate0_z1)),
#        1),
#       (Or(Or(r_3_faulty_gate1_x0, r_3_faulty_gate1_z0),
#           Or(r_3_faulty_gate1_x1, r_3_faulty_gate1_z1)),
#        1),
#       (Or(Or(r_3_faulty_gate2_x0, r_3_faulty_gate2_z0),
#           Or(r_3_faulty_gate2_x1, r_3_faulty_gate2_z1)),
#        1),
#       (Or(Or(r_3_faulty_gate3_x0, r_3_faulty_gate3_z0),
#           Or(r_3_faulty_gate3_x1, r_3_faulty_gate3_z1)),
#        1),
#       (Or(Or(r_3_faulty_gate4_x0, r_3_faulty_gate4_z0),
#           Or(r_3_faulty_gate4_x1, r_3_faulty_gate4_z1)),
#        1),
#       (Or(Or(r_3_faulty_gate5_x0, r_3_faulty_gate5_z0),
#           Or(r_3_faulty_gate5_x1, r_3_faulty_gate5_z1)),
#        1)),
#      1)
#
# 1. Last Round Data Qubits (5 qubits):
#    Data[0]: X=Xor(Xor(Xor(Xor(Xor(False, False), r_0_faulty_gate0_x1),
#             False),
#         r_2_faulty_gate0_x1),
#     r_3_faulty_gate2_x0), Z=Xor(Xor(Xor(Xor(False, r_3_faulty_gate0_x0),
#             r_3_faulty_gate1_x0),
#         Xor(Xor(False, r_0_faulty_gate0_z1),
#             r_2_faulty_gate0_z1)),
#     r_3_faulty_gate2_z0)
#    Data[1]: X=Xor(Xor(Xor(Xor(Xor(False, r_0_faulty_gate2_x0), False),
#             r_1_faulty_gate0_x1),
#         False),
#     r_3_faulty_gate0_x1), Z=Xor(Xor(Xor(Xor(Xor(Xor(False, r_0_faulty_gate0_x0),
#                     r_0_faulty_gate1_x0),
#                 False),
#             r_0_faulty_gate2_z0),
#         r_1_faulty_gate0_z1),
#     r_3_faulty_gate0_z1)
#    Data[2]: X=Xor(Xor(Xor(Xor(False, r_0_faulty_gate3_x0),
#             r_1_faulty_gate2_x0),
#         Xor(Xor(Xor(Xor(Xor(False, r_2_faulty_gate0_x0),
#                         r_2_faulty_gate1_x0),
#                     r_2_faulty_gate2_x1),
#                 r_2_faulty_gate3_x1),
#             r_2_faulty_gate4_x0)),
#     r_2_faulty_gate5_x1), Z=Xor(Xor(Xor(Xor(Xor(False, r_1_faulty_gate0_x0),
#                 r_1_faulty_gate1_x0),
#             Xor(Xor(Xor(Xor(Xor(False, r_0_faulty_gate0_x0),
#                             r_0_faulty_gate1_x0),
#                         r_0_faulty_gate2_x1),
#                     False),
#                 r_0_faulty_gate3_z0)),
#         r_1_faulty_gate2_z0),
#     r_2_faulty_gate5_z1)
#    Data[3]: X=Xor(Xor(Xor(Xor(Xor(Xor(False,
#                         Xor(Xor(Xor(Xor(Xor(False,
#                                         r_0_faulty_gate0_x0),
#                                         r_0_faulty_gate1_x0),
#                                     r_0_faulty_gate2_x1),
#                                 r_0_faulty_gate3_x1),
#                             r_0_faulty_gate4_x0)),
#                     r_0_faulty_gate5_x1),
#                 r_1_faulty_gate3_x0),
#             r_2_faulty_gate2_x0),
#         Xor(Xor(Xor(Xor(Xor(False, r_3_faulty_gate0_x0),
#                         r_3_faulty_gate1_x0),
#                     r_3_faulty_gate2_x1),
#                 r_3_faulty_gate3_x1),
#             r_3_faulty_gate4_x0)),
#     r_3_faulty_gate5_x1), Z=Xor(Xor(Xor(Xor(Xor(False, r_2_faulty_gate0_x0),
#                 r_2_faulty_gate1_x0),
#             Xor(Xor(Xor(Xor(Xor(False, r_1_faulty_gate0_x0),
#                             r_1_faulty_gate1_x0),
#                         r_1_faulty_gate2_x1),
#                     Xor(False, r_0_faulty_gate5_z1)),
#                 r_1_faulty_gate3_z0)),
#         r_2_faulty_gate2_z0),
#     r_3_faulty_gate5_z1)
#    Data[4]: X=Xor(Xor(Xor(Xor(False,
#                 Xor(Xor(Xor(Xor(Xor(False,
#                                     r_1_faulty_gate0_x0),
#                                 r_1_faulty_gate1_x0),
#                             r_1_faulty_gate2_x1),
#                         r_1_faulty_gate3_x1),
#                     r_1_faulty_gate4_x0)),
#             r_1_faulty_gate5_x1),
#         r_2_faulty_gate3_x0),
#     r_3_faulty_gate3_x0), Z=Xor(Xor(Xor(Xor(Xor(False, r_3_faulty_gate0_x0),
#                 r_3_faulty_gate1_x0),
#             r_3_faulty_gate2_x1),
#         Xor(Xor(Xor(Xor(Xor(False, r_2_faulty_gate0_x0),
#                         r_2_faulty_gate1_x0),
#                     r_2_faulty_gate2_x1),
#                 Xor(False, r_1_faulty_gate5_z1)),
#             r_2_faulty_gate3_z0)),
#     r_3_faulty_gate3_z0)
#
# 2. Ancilla & Flag Formulas per Round (6 rounds):
#    Round 0:
#      ancX (Z-basis): 1 measurements
#        ancX[0]: Xor(Xor(Xor(Xor(Xor(Xor(False,
#                         Xor(Xor(False,
#                                 Xor(Xor(Xor(Xor(False,
#                                         False),
#                                         r_0_faulty_gate0_z0),
#                                         False),
#                                     r_0_faulty_gate1_z0)),
#                             r_0_faulty_gate2_z1)),
#                     r_0_faulty_gate3_z1),
#                 Xor(False, r_0_faulty_gate1_z1)),
#             r_0_faulty_gate4_z0),
#         False),
#     r_0_faulty_gate5_z0)
#      ancZ (X-basis): 0 measurements
#      flagX (Z-basis): 0 groups/measurements
#      flagZ (X-basis): 1 groups/measurements
#        flagZ[0]: Xor(Xor(Xor(Xor(False, Xor(False, r_0_faulty_gate0_x0)),
#             r_0_faulty_gate1_x1),
#         Xor(Xor(Xor(Xor(False, r_0_faulty_gate0_x0),
#                     r_0_faulty_gate1_x0),
#                 r_0_faulty_gate2_x1),
#             r_0_faulty_gate3_x1)),
#     r_0_faulty_gate4_x1)
#    Round 1:
#      ancX (Z-basis): 1 measurements
#        ancX[0]: Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(False,
#                                 Xor(Xor(Xor(Xor(Xor(False,
#                                         r_0_faulty_gate0_x0),
#                                         r_0_faulty_gate1_x0),
#                                         r_0_faulty_gate2_x1),
#                                         r_0_faulty_gate3_x1),
#                                     r_0_faulty_gate4_x0)),
#                             r_0_faulty_gate5_x1),
#                         Xor(Xor(Xor(False,
#                                     r_0_faulty_gate3_x0),
#                                 Xor(Xor(Xor(Xor(False,
#                                         Xor(Xor(Xor(Xor(False,
#                                         r_0_faulty_gate0_x0),
#                                         r_0_faulty_gate1_x0),
#                                         False),
#                                         r_0_faulty_gate2_z0)),
#                                         r_1_faulty_gate0_z0),
#                                         False),
#                                     r_1_faulty_gate1_z0)),
#                             r_1_faulty_gate2_z1)),
#                     r_1_faulty_gate3_z1),
#                 Xor(False, r_1_faulty_gate1_z1)),
#             r_1_faulty_gate4_z0),
#         False),
#     r_1_faulty_gate5_z0)
#      ancZ (X-basis): 0 measurements
#      flagX (Z-basis): 0 groups/measurements
#      flagZ (X-basis): 1 groups/measurements
#        flagZ[0]: Xor(Xor(Xor(Xor(False, Xor(False, r_1_faulty_gate0_x0)),
#             r_1_faulty_gate1_x1),
#         Xor(Xor(Xor(Xor(False, r_1_faulty_gate0_x0),
#                     r_1_faulty_gate1_x0),
#                 r_1_faulty_gate2_x1),
#             r_1_faulty_gate3_x1)),
#     r_1_faulty_gate4_x1)
#    Round 2:
#      ancX (Z-basis): 1 measurements
#        ancX[0]: Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(False,
#                                 Xor(Xor(Xor(Xor(Xor(False,
#                                         r_1_faulty_gate0_x0),
#                                         r_1_faulty_gate1_x0),
#                                         r_1_faulty_gate2_x1),
#                                         r_1_faulty_gate3_x1),
#                                     r_1_faulty_gate4_x0)),
#                             r_1_faulty_gate5_x1),
#                         Xor(Xor(Xor(Xor(Xor(False,
#                                         Xor(Xor(Xor(Xor(Xor(False,
#                                         r_0_faulty_gate0_x0),
#                                         r_0_faulty_gate1_x0),
#                                         r_0_faulty_gate2_x1),
#                                         r_0_faulty_gate3_x1),
#                                         r_0_faulty_gate4_x0)),
#                                         r_0_faulty_gate5_x1),
#                                     r_1_faulty_gate3_x0),
#                                 Xor(Xor(Xor(Xor(False,
#                                         Xor(False,
#                                         r_0_faulty_gate0_z1)),
#                                         r_2_faulty_gate0_z0),
#                                         False),
#                                     r_2_faulty_gate1_z0)),
#                             r_2_faulty_gate2_z1)),
#                     r_2_faulty_gate3_z1),
#                 Xor(False, r_2_faulty_gate1_z1)),
#             r_2_faulty_gate4_z0),
#         Xor(Xor(Xor(Xor(False, r_1_faulty_gate0_x0),
#                     r_1_faulty_gate1_x0),
#                 Xor(Xor(Xor(Xor(Xor(False,
#                                     r_0_faulty_gate0_x0),
#                                 r_0_faulty_gate1_x0),
#                             r_0_faulty_gate2_x1),
#                         False),
#                     r_0_faulty_gate3_z0)),
#             r_1_faulty_gate2_z0)),
#     r_2_faulty_gate5_z0)
#      ancZ (X-basis): 0 measurements
#      flagX (Z-basis): 0 groups/measurements
#      flagZ (X-basis): 1 groups/measurements
#        flagZ[0]: Xor(Xor(Xor(Xor(False, Xor(False, r_2_faulty_gate0_x0)),
#             r_2_faulty_gate1_x1),
#         Xor(Xor(Xor(Xor(False, r_2_faulty_gate0_x0),
#                     r_2_faulty_gate1_x0),
#                 r_2_faulty_gate2_x1),
#             r_2_faulty_gate3_x1)),
#     r_2_faulty_gate4_x1)
#    Round 3:
#      ancX (Z-basis): 1 measurements
#        ancX[0]: Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(False,
#                                     Xor(Xor(Xor(Xor(Xor(False,
#                                         r_1_faulty_gate0_x0),
#                                         r_1_faulty_gate1_x0),
#                                         r_1_faulty_gate2_x1),
#                                         r_1_faulty_gate3_x1),
#                                         r_1_faulty_gate4_x0)),
#                                 r_1_faulty_gate5_x1),
#                             r_2_faulty_gate3_x0),
#                         Xor(Xor(Xor(Xor(Xor(Xor(False,
#                                         False),
#                                         r_0_faulty_gate0_x1),
#                                         False),
#                                     r_2_faulty_gate0_x1),
#                                 Xor(Xor(Xor(Xor(False,
#                                         Xor(Xor(Xor(Xor(Xor(False,
#                                         r_0_faulty_gate0_x0),
#                                         r_0_faulty_gate1_x0),
#                                         False),
#                                         r_0_faulty_gate2_z0),
#                                         r_1_faulty_gate0_z1)),
#                                         r_3_faulty_gate0_z0),
#                                         False),
#                                     r_3_faulty_gate1_z0)),
#                             r_3_faulty_gate2_z1)),
#                     r_3_faulty_gate3_z1),
#                 Xor(False, r_3_faulty_gate1_z1)),
#             r_3_faulty_gate4_z0),
#         Xor(Xor(Xor(Xor(False, r_2_faulty_gate0_x0),
#                     r_2_faulty_gate1_x0),
#                 Xor(Xor(Xor(Xor(Xor(False,
#                                     r_1_faulty_gate0_x0),
#                                 r_1_faulty_gate1_x0),
#                             r_1_faulty_gate2_x1),
#                         Xor(False, r_0_faulty_gate5_z1)),
#                     r_1_faulty_gate3_z0)),
#             r_2_faulty_gate2_z0)),
#     r_3_faulty_gate5_z0)
#      ancZ (X-basis): 0 measurements
#      flagX (Z-basis): 0 groups/measurements
#      flagZ (X-basis): 1 groups/measurements
#        flagZ[0]: Xor(Xor(Xor(Xor(False, Xor(False, r_3_faulty_gate0_x0)),
#             r_3_faulty_gate1_x1),
#         Xor(Xor(Xor(Xor(False, r_3_faulty_gate0_x0),
#                     r_3_faulty_gate1_x0),
#                 r_3_faulty_gate2_x1),
#             r_3_faulty_gate3_x1)),
#     r_3_faulty_gate4_x1)
#    Round 4:
#      ancX (Z-basis): 0 measurements
#      ancZ (X-basis): 0 measurements
#      flagX (Z-basis): 0 groups/measurements
#      flagZ (X-basis): 0 groups/measurements
#    Round 5:
#      ancX (Z-basis): 0 measurements
#      ancZ (X-basis): 0 measurements
#      flagX (Z-basis): 0 groups/measurements
#      flagZ (X-basis): 0 groups/measurements
#
# 3. Path Conditions (5 conditions):
#    Condition 0: And(And(Xor(Xor(Xor(Xor(Xor(Xor(False,
#                                 Xor(Xor(False,
#                                         Xor(Xor(Xor(Xor(False,
#                                         False),
#                                         r_0_faulty_gate0_z0),
#                                         False),
#                                         r_0_faulty_gate1_z0)),
#                                     r_0_faulty_gate2_z1)),
#                             r_0_faulty_gate3_z1),
#                         Xor(False, r_0_faulty_gate1_z1)),
#                     r_0_faulty_gate4_z0),
#                 False),
#             r_0_faulty_gate5_z0) ==
#         False),
#     And(Xor(Xor(Xor(Xor(False,
#                         Xor(False, r_0_faulty_gate0_x0)),
#                     r_0_faulty_gate1_x1),
#                 Xor(Xor(Xor(Xor(False, r_0_faulty_gate0_x0),
#                             r_0_faulty_gate1_x0),
#                         r_0_faulty_gate2_x1),
#                     r_0_faulty_gate3_x1)),
#             r_0_faulty_gate4_x1) ==
#         False))
#    Condition 1: And(And(Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(False,
#                                         Xor(Xor(Xor(Xor(Xor(False,
#                                         r_0_faulty_gate0_x0),
#                                         r_0_faulty_gate1_x0),
#                                         r_0_faulty_gate2_x1),
#                                         r_0_faulty_gate3_x1),
#                                         r_0_faulty_gate4_x0)),
#                                     r_0_faulty_gate5_x1),
#                                 Xor(Xor(Xor(False,
#                                         r_0_faulty_gate3_x0),
#                                         Xor(Xor(Xor(Xor(False,
#                                         Xor(Xor(Xor(Xor(False,
#                                         r_0_faulty_gate0_x0),
#                                         r_0_faulty_gate1_x0),
#                                         False),
#                                         r_0_faulty_gate2_z0)),
#                                         r_1_faulty_gate0_z0),
#                                         False),
#                                         r_1_faulty_gate1_z0)),
#                                     r_1_faulty_gate2_z1)),
#                             r_1_faulty_gate3_z1),
#                         Xor(False, r_1_faulty_gate1_z1)),
#                     r_1_faulty_gate4_z0),
#                 False),
#             r_1_faulty_gate5_z0) ==
#         False),
#     And(Xor(Xor(Xor(Xor(False,
#                         Xor(False, r_1_faulty_gate0_x0)),
#                     r_1_faulty_gate1_x1),
#                 Xor(Xor(Xor(Xor(False, r_1_faulty_gate0_x0),
#                             r_1_faulty_gate1_x0),
#                         r_1_faulty_gate2_x1),
#                     r_1_faulty_gate3_x1)),
#             r_1_faulty_gate4_x1) ==
#         False))
#    Condition 2: And(And(Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(False,
#                                         Xor(Xor(Xor(Xor(Xor(False,
#                                         r_1_faulty_gate0_x0),
#                                         r_1_faulty_gate1_x0),
#                                         r_1_faulty_gate2_x1),
#                                         r_1_faulty_gate3_x1),
#                                         r_1_faulty_gate4_x0)),
#                                     r_1_faulty_gate5_x1),
#                                 Xor(Xor(Xor(Xor(Xor(False,
#                                         Xor(Xor(Xor(Xor(Xor(False,
#                                         r_0_faulty_gate0_x0),
#                                         r_0_faulty_gate1_x0),
#                                         r_0_faulty_gate2_x1),
#                                         r_0_faulty_gate3_x1),
#                                         r_0_faulty_gate4_x0)),
#                                         r_0_faulty_gate5_x1),
#                                         r_1_faulty_gate3_x0),
#                                         Xor(Xor(Xor(Xor(False,
#                                         Xor(False,
#                                         r_0_faulty_gate0_z1)),
#                                         r_2_faulty_gate0_z0),
#                                         False),
#                                         r_2_faulty_gate1_z0)),
#                                     r_2_faulty_gate2_z1)),
#                             r_2_faulty_gate3_z1),
#                         Xor(False, r_2_faulty_gate1_z1)),
#                     r_2_faulty_gate4_z0),
#                 Xor(Xor(Xor(Xor(False, r_1_faulty_gate0_x0),
#                             r_1_faulty_gate1_x0),
#                         Xor(Xor(Xor(Xor(Xor(False,
#                                         r_0_faulty_gate0_x0),
#                                         r_0_faulty_gate1_x0),
#                                     r_0_faulty_gate2_x1),
#                                 False),
#                             r_0_faulty_gate3_z0)),
#                     r_1_faulty_gate2_z0)),
#             r_2_faulty_gate5_z0) ==
#         False),
#     And(Xor(Xor(Xor(Xor(False,
#                         Xor(False, r_2_faulty_gate0_x0)),
#                     r_2_faulty_gate1_x1),
#                 Xor(Xor(Xor(Xor(False, r_2_faulty_gate0_x0),
#                             r_2_faulty_gate1_x0),
#                         r_2_faulty_gate2_x1),
#                     r_2_faulty_gate3_x1)),
#             r_2_faulty_gate4_x1) ==
#         False))
#    Condition 3: And(And(Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(False,
#                                         Xor(Xor(Xor(Xor(Xor(False,
#                                         r_1_faulty_gate0_x0),
#                                         r_1_faulty_gate1_x0),
#                                         r_1_faulty_gate2_x1),
#                                         r_1_faulty_gate3_x1),
#                                         r_1_faulty_gate4_x0)),
#                                         r_1_faulty_gate5_x1),
#                                     r_2_faulty_gate3_x0),
#                                 Xor(Xor(Xor(Xor(Xor(Xor(False,
#                                         False),
#                                         r_0_faulty_gate0_x1),
#                                         False),
#                                         r_2_faulty_gate0_x1),
#                                         Xor(Xor(Xor(Xor(False,
#                                         Xor(Xor(Xor(Xor(Xor(False,
#                                         r_0_faulty_gate0_x0),
#                                         r_0_faulty_gate1_x0),
#                                         False),
#                                         r_0_faulty_gate2_z0),
#                                         r_1_faulty_gate0_z1)),
#                                         r_3_faulty_gate0_z0),
#                                         False),
#                                         r_3_faulty_gate1_z0)),
#                                     r_3_faulty_gate2_z1)),
#                             r_3_faulty_gate3_z1),
#                         Xor(False, r_3_faulty_gate1_z1)),
#                     r_3_faulty_gate4_z0),
#                 Xor(Xor(Xor(Xor(False, r_2_faulty_gate0_x0),
#                             r_2_faulty_gate1_x0),
#                         Xor(Xor(Xor(Xor(Xor(False,
#                                         r_1_faulty_gate0_x0),
#                                         r_1_faulty_gate1_x0),
#                                     r_1_faulty_gate2_x1),
#                                 Xor(False,
#                                     r_0_faulty_gate5_z1)),
#                             r_1_faulty_gate3_z0)),
#                     r_2_faulty_gate2_z0)),
#             r_3_faulty_gate5_z0) ==
#         False),
#     And(Xor(Xor(Xor(Xor(False,
#                         Xor(False, r_3_faulty_gate0_x0)),
#                     r_3_faulty_gate1_x1),
#                 Xor(Xor(Xor(Xor(False, r_3_faulty_gate0_x0),
#                             r_3_faulty_gate1_x0),
#                         r_3_faulty_gate2_x1),
#                     r_3_faulty_gate3_x1)),
#             r_3_faulty_gate4_x1) ==
#         False))
#    Condition 4: True
#
# --- PATH 2 ---
#
# Measured syndrome:
#    [Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(False, r_0_faulty_gate3_x0),
#                             r_1_faulty_gate2_x0),
#                         Xor(Xor(Xor(Xor(Xor(False,
#                                         r_2_faulty_gate0_x0),
#                                         r_2_faulty_gate1_x0),
#                                     r_2_faulty_gate2_x1),
#                                 r_2_faulty_gate3_x1),
#                             r_2_faulty_gate4_x0)),
#                     r_2_faulty_gate5_x1),
#                 Xor(Xor(Xor(Xor(Xor(Xor(Xor(False,
#                                         r_0_faulty_gate2_x0),
#                                         False),
#                                     r_1_faulty_gate0_x1),
#                                 False),
#                             r_3_faulty_gate0_x1),
#                         Xor(Xor(False,
#                                 Xor(Xor(Xor(Xor(False,
#                                         r_3_faulty_gate0_x0),
#                                         r_3_faulty_gate1_x0),
#                                         Xor(Xor(False,
#                                         r_0_faulty_gate0_z1),
#                                         r_2_faulty_gate0_z1)),
#                                     r_3_faulty_gate2_z0)),
#                             r_4_faulty_gate0_z0)),
#                     r_4_faulty_gate1_z1)),
#             r_4_faulty_gate2_z1),
#         Xor(Xor(Xor(Xor(Xor(False, r_2_faulty_gate0_x0),
#                         r_2_faulty_gate1_x0),
#                     Xor(Xor(Xor(Xor(Xor(False,
#                                         r_1_faulty_gate0_x0),
#                                     r_1_faulty_gate1_x0),
#                                 r_1_faulty_gate2_x1),
#                             Xor(False, r_0_faulty_gate5_z1)),
#                         r_1_faulty_gate3_z0)),
#                 r_2_faulty_gate2_z0),
#             r_3_faulty_gate5_z1)),
#     r_4_faulty_gate3_z0), Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(False,
#                                         Xor(Xor(Xor(Xor(Xor(False,
#                                         r_0_faulty_gate0_x0),
#                                         r_0_faulty_gate1_x0),
#                                         r_0_faulty_gate2_x1),
#                                         r_0_faulty_gate3_x1),
#                                         r_0_faulty_gate4_x0)),
#                                         r_0_faulty_gate5_x1),
#                                         r_1_faulty_gate3_x0),
#                                     r_2_faulty_gate2_x0),
#                                 Xor(Xor(Xor(Xor(Xor(False,
#                                         r_3_faulty_gate0_x0),
#                                         r_3_faulty_gate1_x0),
#                                         r_3_faulty_gate2_x1),
#                                         r_3_faulty_gate3_x1),
#                                     r_3_faulty_gate4_x0)),
#                             r_3_faulty_gate5_x1),
#                         Xor(Xor(Xor(False,
#                                     r_4_faulty_gate0_x0),
#                                 r_4_faulty_gate1_x1),
#                             r_4_faulty_gate2_x1)),
#                     r_4_faulty_gate3_x1),
#                 Xor(Xor(Xor(Xor(Xor(Xor(Xor(False,
#                                         r_0_faulty_gate3_x0),
#                                         r_1_faulty_gate2_x0),
#                                     Xor(Xor(Xor(Xor(Xor(False,
#                                         r_2_faulty_gate0_x0),
#                                         r_2_faulty_gate1_x0),
#                                         r_2_faulty_gate2_x1),
#                                         r_2_faulty_gate3_x1),
#                                         r_2_faulty_gate4_x0)),
#                                 r_2_faulty_gate5_x1),
#                             r_4_faulty_gate2_x0),
#                         Xor(Xor(False,
#                                 Xor(Xor(Xor(False,
#                                         r_4_faulty_gate0_x0),
#                                         Xor(Xor(Xor(Xor(Xor(Xor(False,
#                                         r_0_faulty_gate0_x0),
#                                         r_0_faulty_gate1_x0),
#                                         False),
#                                         r_0_faulty_gate2_z0),
#                                         r_1_faulty_gate0_z1),
#                                         r_3_faulty_gate0_z1)),
#                                     r_4_faulty_gate1_z0)),
#                             r_4_faulty_gate4_z0)),
#                     r_4_faulty_gate5_z1)),
#             r_4_faulty_gate6_z1),
#         Xor(Xor(Xor(Xor(Xor(False, r_3_faulty_gate0_x0),
#                         r_3_faulty_gate1_x0),
#                     r_3_faulty_gate2_x1),
#                 Xor(Xor(Xor(Xor(Xor(False,
#                                     r_2_faulty_gate0_x0),
#                                 r_2_faulty_gate1_x0),
#                             r_2_faulty_gate2_x1),
#                         Xor(False, r_1_faulty_gate5_z1)),
#                     r_2_faulty_gate3_z0)),
#             r_3_faulty_gate3_z0)),
#     r_4_faulty_gate7_z0), Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(False,
#                                         Xor(Xor(Xor(Xor(Xor(False,
#                                         r_1_faulty_gate0_x0),
#                                         r_1_faulty_gate1_x0),
#                                         r_1_faulty_gate2_x1),
#                                         r_1_faulty_gate3_x1),
#                                         r_1_faulty_gate4_x0)),
#                                     r_1_faulty_gate5_x1),
#                                 r_2_faulty_gate3_x0),
#                             r_3_faulty_gate3_x0),
#                         Xor(Xor(Xor(False,
#                                     r_4_faulty_gate4_x0),
#                                 r_4_faulty_gate5_x1),
#                             r_4_faulty_gate6_x1)),
#                     r_4_faulty_gate7_x1),
#                 Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(False,
#                                         Xor(Xor(Xor(Xor(Xor(False,
#                                         r_0_faulty_gate0_x0),
#                                         r_0_faulty_gate1_x0),
#                                         r_0_faulty_gate2_x1),
#                                         r_0_faulty_gate3_x1),
#                                         r_0_faulty_gate4_x0)),
#                                         r_0_faulty_gate5_x1),
#                                         r_1_faulty_gate3_x0),
#                                         r_2_faulty_gate2_x0),
#                                         Xor(Xor(Xor(Xor(Xor(False,
#                                         r_3_faulty_gate0_x0),
#                                         r_3_faulty_gate1_x0),
#                                         r_3_faulty_gate2_x1),
#                                         r_3_faulty_gate3_x1),
#                                         r_3_faulty_gate4_x0)),
#                                         r_3_faulty_gate5_x1),
#                                     Xor(Xor(Xor(False,
#                                         r_4_faulty_gate0_x0),
#                                         r_4_faulty_gate1_x1),
#                                         r_4_faulty_gate2_x1)),
#                                 r_4_faulty_gate3_x1),
#                             r_4_faulty_gate6_x0),
#                         Xor(Xor(False,
#                                 Xor(Xor(Xor(Xor(Xor(False,
#                                         r_3_faulty_gate0_x0),
#                                         r_3_faulty_gate1_x0),
#                                         Xor(Xor(False,
#                                         r_0_faulty_gate0_z1),
#                                         r_2_faulty_gate0_z1)),
#                                         r_3_faulty_gate2_z0),
#                                     r_4_faulty_gate0_z1)),
#                             r_4_faulty_gate8_z0)),
#                     r_4_faulty_gate9_z1)),
#             r_4_faulty_gate10_z1),
#         Xor(Xor(Xor(False, r_4_faulty_gate4_x0),
#                 Xor(Xor(Xor(Xor(False, r_4_faulty_gate0_x0),
#                             r_4_faulty_gate1_x1),
#                         Xor(Xor(Xor(Xor(Xor(False,
#                                         r_1_faulty_gate0_x0),
#                                         r_1_faulty_gate1_x0),
#                                     Xor(Xor(Xor(Xor(Xor(False,
#                                         r_0_faulty_gate0_x0),
#                                         r_0_faulty_gate1_x0),
#                                         r_0_faulty_gate2_x1),
#                                         False),
#                                         r_0_faulty_gate3_z0)),
#                                 r_1_faulty_gate2_z0),
#                             r_2_faulty_gate5_z1)),
#                     r_4_faulty_gate2_z0)),
#             r_4_faulty_gate5_z0)),
#     r_4_faulty_gate11_z0), Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(False,
#                                         Xor(Xor(Xor(Xor(Xor(False,
#                                         r_1_faulty_gate0_x0),
#                                         r_1_faulty_gate1_x0),
#                                         r_1_faulty_gate2_x1),
#                                         r_1_faulty_gate3_x1),
#                                         r_1_faulty_gate4_x0)),
#                                         r_1_faulty_gate5_x1),
#                                     r_2_faulty_gate3_x0),
#                                 r_3_faulty_gate3_x0),
#                             Xor(Xor(Xor(False,
#                                         r_4_faulty_gate4_x0),
#                                     r_4_faulty_gate5_x1),
#                                 r_4_faulty_gate6_x1)),
#                         r_4_faulty_gate7_x1),
#                     r_4_faulty_gate10_x0),
#                 Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(False,
#                                         False),
#                                         r_0_faulty_gate0_x1),
#                                         False),
#                                         r_2_faulty_gate0_x1),
#                                         r_3_faulty_gate2_x0),
#                                         False),
#                                     r_4_faulty_gate0_x1),
#                                 False),
#                             r_4_faulty_gate8_x1),
#                         Xor(Xor(False,
#                                 Xor(Xor(Xor(Xor(False,
#                                         r_4_faulty_gate0_x0),
#                                         Xor(Xor(Xor(Xor(Xor(Xor(False,
#                                         r_0_faulty_gate0_x0),
#                                         r_0_faulty_gate1_x0),
#                                         False),
#                                         r_0_faulty_gate2_z0),
#                                         r_1_faulty_gate0_z1),
#                                         r_3_faulty_gate0_z1)),
#                                         r_4_faulty_gate1_z0),
#                                     r_4_faulty_gate4_z1)),
#                             r_4_faulty_gate12_z0)),
#                     r_4_faulty_gate13_z1)),
#             r_4_faulty_gate14_z1),
#         Xor(Xor(Xor(False, r_4_faulty_gate8_x0),
#                 Xor(Xor(Xor(Xor(False, r_4_faulty_gate4_x0),
#                             r_4_faulty_gate5_x1),
#                         Xor(Xor(Xor(Xor(Xor(Xor(False,
#                                         r_2_faulty_gate0_x0),
#                                         r_2_faulty_gate1_x0),
#                                         Xor(Xor(Xor(Xor(Xor(False,
#                                         r_1_faulty_gate0_x0),
#                                         r_1_faulty_gate1_x0),
#                                         r_1_faulty_gate2_x1),
#                                         Xor(False,
#                                         r_0_faulty_gate5_z1)),
#                                         r_1_faulty_gate3_z0)),
#                                     r_2_faulty_gate2_z0),
#                                 r_3_faulty_gate5_z1),
#                             r_4_faulty_gate3_z1)),
#                     r_4_faulty_gate6_z0)),
#             r_4_faulty_gate9_z0)),
#     r_4_faulty_gate15_z0)]
#
# Commutation syndrome:
#    [((((r_4_faulty_gate12_x0 ==
#     (((((r_0_faulty_gate0_z1 == r_2_faulty_gate0_z1) ==
#         (r_3_faulty_gate0_x0 == r_3_faulty_gate1_x0)) ==
#        r_3_faulty_gate2_z0) ==
#       r_4_faulty_gate0_z1) ==
#      r_4_faulty_gate8_z1)) ==
#    r_4_faulty_gate13_z0) ==
#   (((((r_0_faulty_gate2_x0 == r_1_faulty_gate0_x1) ==
#       r_3_faulty_gate0_x1) ==
#      r_4_faulty_gate1_x0) ==
#     r_4_faulty_gate4_x1) ==
#    r_4_faulty_gate12_x1)) ==
#  (((((((r_0_faulty_gate3_x0 == r_1_faulty_gate2_x0) ==
#        ((((r_2_faulty_gate0_x0 == r_2_faulty_gate1_x0) ==
#           r_2_faulty_gate2_x1) ==
#          r_2_faulty_gate3_x1) ==
#         r_2_faulty_gate4_x0)) ==
#       r_2_faulty_gate5_x1) ==
#      r_4_faulty_gate2_x0) ==
#     r_4_faulty_gate5_x0) ==
#    ((r_4_faulty_gate8_x0 == r_4_faulty_gate9_x1) ==
#     r_4_faulty_gate10_x1)) ==
#   r_4_faulty_gate11_x1)) ==
# (((r_4_faulty_gate8_x0 ==
#    (((((((r_2_faulty_gate0_x0 == r_2_faulty_gate1_x0) ==
#          ((((r_1_faulty_gate0_x0 == r_1_faulty_gate1_x0) ==
#             r_1_faulty_gate2_x1) ==
#            r_0_faulty_gate5_z1) ==
#           r_1_faulty_gate3_z0)) ==
#         r_2_faulty_gate2_z0) ==
#        r_3_faulty_gate5_z1) ==
#       r_4_faulty_gate3_z1) ==
#      (r_4_faulty_gate4_x0 == r_4_faulty_gate5_x1)) ==
#     r_4_faulty_gate6_z0)) ==
#   r_4_faulty_gate9_z0) ==
#  r_4_faulty_gate15_z1), ((((((r_4_faulty_gate0_x0 ==
#       ((((r_0_faulty_gate0_x0 == r_0_faulty_gate1_x0) ==
#          r_0_faulty_gate2_z0) ==
#         r_1_faulty_gate0_z1) ==
#        r_3_faulty_gate0_z1)) ==
#      r_4_faulty_gate1_z0) ==
#     r_4_faulty_gate4_z1) ==
#    r_4_faulty_gate12_z1) ==
#   (((((((r_0_faulty_gate3_x0 == r_1_faulty_gate2_x0) ==
#         ((((r_2_faulty_gate0_x0 == r_2_faulty_gate1_x0) ==
#            r_2_faulty_gate2_x1) ==
#           r_2_faulty_gate3_x1) ==
#          r_2_faulty_gate4_x0)) ==
#        r_2_faulty_gate5_x1) ==
#       r_4_faulty_gate2_x0) ==
#      r_4_faulty_gate5_x0) ==
#     ((r_4_faulty_gate8_x0 == r_4_faulty_gate9_x1) ==
#      r_4_faulty_gate10_x1)) ==
#    r_4_faulty_gate11_x1)) ==
#  (((((((((((((((r_0_faulty_gate0_x0 == r_0_faulty_gate1_x0) ==
#                r_0_faulty_gate2_x1) ==
#               r_0_faulty_gate3_x1) ==
#              r_0_faulty_gate4_x0) ==
#             r_0_faulty_gate5_x1) ==
#            r_1_faulty_gate3_x0) ==
#           r_2_faulty_gate2_x0) ==
#          ((((r_3_faulty_gate0_x0 == r_3_faulty_gate1_x0) ==
#             r_3_faulty_gate2_x1) ==
#            r_3_faulty_gate3_x1) ==
#           r_3_faulty_gate4_x0)) ==
#         r_3_faulty_gate5_x1) ==
#        ((r_4_faulty_gate0_x0 == r_4_faulty_gate1_x1) ==
#         r_4_faulty_gate2_x1)) ==
#       r_4_faulty_gate3_x1) ==
#      r_4_faulty_gate6_x0) ==
#     r_4_faulty_gate9_x0) ==
#    ((r_4_faulty_gate12_x0 == r_4_faulty_gate13_x1) ==
#     r_4_faulty_gate14_x1)) ==
#   r_4_faulty_gate15_x1)) ==
# (((r_4_faulty_gate12_x0 == r_4_faulty_gate13_x1) ==
#   (((((((r_3_faulty_gate0_x0 == r_3_faulty_gate1_x0) ==
#         r_3_faulty_gate2_x1) ==
#        ((((r_2_faulty_gate0_x0 == r_2_faulty_gate1_x0) ==
#           r_2_faulty_gate2_x1) ==
#          r_1_faulty_gate5_z1) ==
#         r_2_faulty_gate3_z0)) ==
#       r_3_faulty_gate3_z0) ==
#      r_4_faulty_gate7_z1) ==
#     (r_4_faulty_gate8_x0 == r_4_faulty_gate9_x1)) ==
#    r_4_faulty_gate10_z0)) ==
#  r_4_faulty_gate14_z0), ((((r_4_faulty_gate12_x0 ==
#     (((((r_0_faulty_gate0_z1 == r_2_faulty_gate0_z1) ==
#         (r_3_faulty_gate0_x0 == r_3_faulty_gate1_x0)) ==
#        r_3_faulty_gate2_z0) ==
#       r_4_faulty_gate0_z1) ==
#      r_4_faulty_gate8_z1)) ==
#    r_4_faulty_gate13_z0) ==
#   (((r_4_faulty_gate4_x0 ==
#      ((((((((r_0_faulty_gate0_x0 == r_0_faulty_gate1_x0) ==
#             r_0_faulty_gate2_x1) ==
#            r_0_faulty_gate3_z0) ==
#           (r_1_faulty_gate0_x0 == r_1_faulty_gate1_x0)) ==
#          r_1_faulty_gate2_z0) ==
#         r_2_faulty_gate5_z1) ==
#        (r_4_faulty_gate0_x0 == r_4_faulty_gate1_x1)) ==
#       r_4_faulty_gate2_z0)) ==
#     r_4_faulty_gate5_z0) ==
#    r_4_faulty_gate11_z1)) ==
#  (((((((((((((((r_0_faulty_gate0_x0 == r_0_faulty_gate1_x0) ==
#                r_0_faulty_gate2_x1) ==
#               r_0_faulty_gate3_x1) ==
#              r_0_faulty_gate4_x0) ==
#             r_0_faulty_gate5_x1) ==
#            r_1_faulty_gate3_x0) ==
#           r_2_faulty_gate2_x0) ==
#          ((((r_3_faulty_gate0_x0 == r_3_faulty_gate1_x0) ==
#             r_3_faulty_gate2_x1) ==
#            r_3_faulty_gate3_x1) ==
#           r_3_faulty_gate4_x0)) ==
#         r_3_faulty_gate5_x1) ==
#        ((r_4_faulty_gate0_x0 == r_4_faulty_gate1_x1) ==
#         r_4_faulty_gate2_x1)) ==
#       r_4_faulty_gate3_x1) ==
#      r_4_faulty_gate6_x0) ==
#     r_4_faulty_gate9_x0) ==
#    ((r_4_faulty_gate12_x0 == r_4_faulty_gate13_x1) ==
#     r_4_faulty_gate14_x1)) ==
#   r_4_faulty_gate15_x1)) ==
# (((((((((((r_1_faulty_gate0_x0 == r_1_faulty_gate1_x0) ==
#           r_1_faulty_gate2_x1) ==
#          r_1_faulty_gate3_x1) ==
#         r_1_faulty_gate4_x0) ==
#        r_1_faulty_gate5_x1) ==
#       r_2_faulty_gate3_x0) ==
#      r_3_faulty_gate3_x0) ==
#     ((r_4_faulty_gate4_x0 == r_4_faulty_gate5_x1) ==
#      r_4_faulty_gate6_x1)) ==
# ...
#                 Xor(Xor(Xor(Xor(False, r_0_faulty_gate3_x0),
#                             r_1_faulty_gate2_x0),
#                         Xor(Xor(False,
#                                 Xor(Xor(Xor(False,
#                                         r_1_faulty_gate0_x0),
#                                         Xor(Xor(Xor(Xor(False,
#                                         r_0_faulty_gate0_x0),
#                                         r_0_faulty_gate1_x0),
#                                         False),
#                                         r_0_faulty_gate2_z0)),
#                                     r_1_faulty_gate1_z0)),
#                             r_1_faulty_gate4_z0)),
#                     r_1_faulty_gate5_z1)),
#             r_1_faulty_gate6_z1),
#         False),
#     r_1_faulty_gate7_z0)
#        ancX[2]: Xor(Xor(Xor(Xor(Xor(Xor(False,
#                         Xor(Xor(Xor(False,
#                                     r_1_faulty_gate4_x0),
#                                 r_1_faulty_gate5_x1),
#                             r_1_faulty_gate6_x1)),
#                     r_1_faulty_gate7_x1),
#                 Xor(Xor(Xor(Xor(Xor(Xor(Xor(False,
#                                         Xor(Xor(Xor(Xor(Xor(False,
#                                         r_0_faulty_gate0_x0),
#                                         r_0_faulty_gate1_x0),
#                                         r_0_faulty_gate2_x1),
#                                         r_0_faulty_gate3_x1),
#                                         r_0_faulty_gate4_x0)),
#                                         r_0_faulty_gate5_x1),
#                                     Xor(Xor(Xor(False,
#                                         r_1_faulty_gate0_x0),
#                                         r_1_faulty_gate1_x1),
#                                         r_1_faulty_gate2_x1)),
#                                 r_1_faulty_gate3_x1),
#                             r_1_faulty_gate6_x0),
#                         Xor(Xor(False,
#                                 Xor(Xor(False,
#                                         r_0_faulty_gate0_z1),
#                                     r_1_faulty_gate0_z1)),
#                             r_1_faulty_gate8_z0)),
#                     r_1_faulty_gate9_z1)),
#             r_1_faulty_gate10_z1),
#         Xor(Xor(Xor(False, r_1_faulty_gate4_x0),
#                 Xor(Xor(Xor(Xor(False, r_1_faulty_gate0_x0),
#                             r_1_faulty_gate1_x1),
#                         Xor(Xor(Xor(Xor(Xor(False,
#                                         r_0_faulty_gate0_x0),
#                                         r_0_faulty_gate1_x0),
#                                     r_0_faulty_gate2_x1),
#                                 False),
#                             r_0_faulty_gate3_z0)),
#                     r_1_faulty_gate2_z0)),
#             r_1_faulty_gate5_z0)),
#     r_1_faulty_gate11_z0)
#        ancX[3]: Xor(Xor(Xor(Xor(Xor(Xor(Xor(False,
#                             Xor(Xor(Xor(False,
#                                         r_1_faulty_gate4_x0),
#                                     r_1_faulty_gate5_x1),
#                                 r_1_faulty_gate6_x1)),
#                         r_1_faulty_gate7_x1),
#                     r_1_faulty_gate10_x0),
#                 Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(False,
#                                         False),
#                                         r_0_faulty_gate0_x1),
#                                         False),
#                                     r_1_faulty_gate0_x1),
#                                 False),
#                             r_1_faulty_gate8_x1),
#                         Xor(Xor(False,
#                                 Xor(Xor(Xor(Xor(False,
#                                         r_1_faulty_gate0_x0),
#                                         Xor(Xor(Xor(Xor(False,
#                                         r_0_faulty_gate0_x0),
#                                         r_0_faulty_gate1_x0),
#                                         False),
#                                         r_0_faulty_gate2_z0)),
#                                         r_1_faulty_gate1_z0),
#                                     r_1_faulty_gate4_z1)),
#                             r_1_faulty_gate12_z0)),
#                     r_1_faulty_gate13_z1)),
#             r_1_faulty_gate14_z1),
#         Xor(Xor(Xor(False, r_1_faulty_gate8_x0),
#                 Xor(Xor(Xor(Xor(False, r_1_faulty_gate4_x0),
#                             r_1_faulty_gate5_x1),
#                         Xor(Xor(False, r_0_faulty_gate5_z1),
#                             r_1_faulty_gate3_z1)),
#                     r_1_faulty_gate6_z0)),
#             r_1_faulty_gate9_z0)),
#     r_1_faulty_gate15_z0)
#      ancZ (X-basis): 0 measurements
#      flagX (Z-basis): 0 groups/measurements
#      flagZ (X-basis): 0 groups/measurements
#    Round 2:
#      ancX (Z-basis): 0 measurements
#      ancZ (X-basis): 0 measurements
#      flagX (Z-basis): 0 groups/measurements
#      flagZ (X-basis): 0 groups/measurements
#
# 3. Path Conditions (3 conditions):
#    Condition 0: Not(And(And(Xor(Xor(Xor(Xor(Xor(Xor(False,
#                                     Xor(Xor(False,
#                                         Xor(Xor(Xor(Xor(False,
#                                         False),
#                                         r_0_faulty_gate0_z0),
#                                         False),
#                                         r_0_faulty_gate1_z0)),
#                                         r_0_faulty_gate2_z1)),
#                                 r_0_faulty_gate3_z1),
#                             Xor(False, r_0_faulty_gate1_z1)),
#                         r_0_faulty_gate4_z0),
#                     False),
#                 r_0_faulty_gate5_z0) ==
#             False),
#         And(Xor(Xor(Xor(Xor(False,
#                             Xor(False, r_0_faulty_gate0_x0)),
#                         r_0_faulty_gate1_x1),
#                     Xor(Xor(Xor(Xor(False,
#                                     r_0_faulty_gate0_x0),
#                                 r_0_faulty_gate1_x0),
#                             r_0_faulty_gate2_x1),
#                         r_0_faulty_gate3_x1)),
#                 r_0_faulty_gate4_x1) ==
#             False)))
#    Condition 1: True
#    Condition 2: And(Xor(Xor(Xor(Xor(Xor(False, r_0_faulty_gate3_x0),
#                     Xor(Xor(Xor(False, r_0_faulty_gate2_x0),
#                             Xor(Xor(False,
#                                     Xor(False,
#                                         r_0_faulty_gate0_z1)),
#                                 r_1_faulty_gate0_z0)),
#                         r_1_faulty_gate1_z1)),
#                 r_1_faulty_gate2_z1),
#             Xor(False, r_0_faulty_gate5_z1)),
#         r_1_faulty_gate3_z0) ==
#     Not((((r_1_faulty_gate8_x0 ==
#            (((r_0_faulty_gate5_z1 == r_1_faulty_gate3_z1) ==
#              (r_1_faulty_gate4_x0 == r_1_faulty_gate5_x1)) ==
#             r_1_faulty_gate6_z0)) ==
#           r_1_faulty_gate9_z0) ==
#          r_1_faulty_gate15_z1) ==
#         ((((r_1_faulty_gate12_x0 ==
#             ((r_0_faulty_gate0_z1 == r_1_faulty_gate0_z1) ==
#              r_1_faulty_gate8_z1)) ==
#            r_1_faulty_gate13_z0) ==
#           (((r_0_faulty_gate2_x0 == r_1_faulty_gate1_x0) ==
#             r_1_faulty_gate4_x1) ==
#            r_1_faulty_gate12_x1)) ==
#          ((((r_0_faulty_gate3_x0 == r_1_faulty_gate2_x0) ==
#             r_1_faulty_gate5_x0) ==
#            ((r_1_faulty_gate8_x0 == r_1_faulty_gate9_x1) ==
#             r_1_faulty_gate10_x1)) ==
#           r_1_faulty_gate11_x1))),
#     Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(False,
#                                     Xor(Xor(Xor(Xor(Xor(False,
#                                         r_0_faulty_gate0_x0),
#                                         r_0_faulty_gate1_x0),
#                                         r_0_faulty_gate2_x1),
#                                         r_0_faulty_gate3_x1),
#                                         r_0_faulty_gate4_x0)),
#                                 r_0_faulty_gate5_x1),
#                             Xor(Xor(Xor(False,
#                                         r_1_faulty_gate0_x0),
#                                     r_1_faulty_gate1_x1),
#                                 r_1_faulty_gate2_x1)),
#                         r_1_faulty_gate3_x1),
#                     Xor(Xor(Xor(Xor(False,
#                                     r_0_faulty_gate3_x0),
#                                 r_1_faulty_gate2_x0),
#                             Xor(Xor(False,
#                                     Xor(Xor(Xor(False,
#                                         r_1_faulty_gate0_x0),
#                                         Xor(Xor(Xor(Xor(False,
#                                         r_0_faulty_gate0_x0),
#                                         r_0_faulty_gate1_x0),
#                                         False),
#                                         r_0_faulty_gate2_z0)),
#                                         r_1_faulty_gate1_z0)),
#                                 r_1_faulty_gate4_z0)),
#                         r_1_faulty_gate5_z1)),
#                 r_1_faulty_gate6_z1),
#             False),
#         r_1_faulty_gate7_z0) ==
#     (((((((((((((r_0_faulty_gate0_x0 == r_0_faulty_gate1_x0) ==
#                 r_0_faulty_gate2_x1) ==
#                r_0_faulty_gate3_x1) ==
#               r_0_faulty_gate4_x0) ==
#              r_0_faulty_gate5_x1) ==
#             ((r_1_faulty_gate0_x0 == r_1_faulty_gate1_x1) ==
#              r_1_faulty_gate2_x1)) ==
#            r_1_faulty_gate3_x1) ==
#           r_1_faulty_gate6_x0) ==
#          r_1_faulty_gate9_x0) ==
#         ((r_1_faulty_gate12_x0 == r_1_faulty_gate13_x1) ==
#          r_1_faulty_gate14_x1)) ==
#        r_1_faulty_gate15_x1) ==
#       (((((r_1_faulty_gate0_x0 ==
#            ((r_0_faulty_gate0_x0 == r_0_faulty_gate1_x0) ==
#             r_0_faulty_gate2_z0)) ==
#           r_1_faulty_gate1_z0) ==
#          r_1_faulty_gate4_z1) ==
#         r_1_faulty_gate12_z1) ==
#        ((((r_0_faulty_gate3_x0 == r_1_faulty_gate2_x0) ==
#           r_1_faulty_gate5_x0) ==
#          ((r_1_faulty_gate8_x0 == r_1_faulty_gate9_x1) ==
#           r_1_faulty_gate10_x1)) ==
#         r_1_faulty_gate11_x1))) ==
#      (((((r_1_faulty_gate8_x0 == r_1_faulty_gate9_x1) ==
#          r_1_faulty_gate7_z1) ==
#         r_1_faulty_gate10_z0) ==
#        (r_1_faulty_gate12_x0 == r_1_faulty_gate13_x1)) ==
#       r_1_faulty_gate14_z0)),
#     Xor(Xor(Xor(Xor(Xor(Xor(False,
#                             Xor(Xor(Xor(False,
#                                         r_1_faulty_gate4_x0),
#                                     r_1_faulty_gate5_x1),
#                                 r_1_faulty_gate6_x1)),
#                         r_1_faulty_gate7_x1),
#                     Xor(Xor(Xor(Xor(Xor(Xor(Xor(False,
#                                         Xor(Xor(Xor(Xor(Xor(False,
#                                         r_0_faulty_gate0_x0),
#                                         r_0_faulty_gate1_x0),
#                                         r_0_faulty_gate2_x1),
#                                         r_0_faulty_gate3_x1),
#                                         r_0_faulty_gate4_x0)),
#                                         r_0_faulty_gate5_x1),
#                                         Xor(Xor(Xor(False,
#                                         r_1_faulty_gate0_x0),
#                                         r_1_faulty_gate1_x1),
#                                         r_1_faulty_gate2_x1)),
#                                     r_1_faulty_gate3_x1),
#                                 r_1_faulty_gate6_x0),
#                             Xor(Xor(False,
#                                     Xor(Xor(False,
#                                         r_0_faulty_gate0_z1),
#                                         r_1_faulty_gate0_z1)),
#                                 r_1_faulty_gate8_z0)),
#                         r_1_faulty_gate9_z1)),
#                 r_1_faulty_gate10_z1),
#             Xor(Xor(Xor(False, r_1_faulty_gate4_x0),
#                     Xor(Xor(Xor(Xor(False,
#                                     r_1_faulty_gate0_x0),
#                                 r_1_faulty_gate1_x1),
#                             Xor(Xor(Xor(Xor(Xor(False,
#                                         r_0_faulty_gate0_x0),
#                                         r_0_faulty_gate1_x0),
#                                         r_0_faulty_gate2_x1),
#                                     False),
#                                 r_0_faulty_gate3_z0)),
#                         r_1_faulty_gate2_z0)),
#                 r_1_faulty_gate5_z0)),
#         r_1_faulty_gate11_z0) ==
#     (((((r_1_faulty_gate12_x0 ==
#          ((r_0_faulty_gate0_z1 == r_1_faulty_gate0_z1) ==
#           r_1_faulty_gate8_z1)) ==
#         r_1_faulty_gate13_z0) ==
#        (((r_1_faulty_gate4_x0 ==
#           (((((r_0_faulty_gate0_x0 == r_0_faulty_gate1_x0) ==
#               r_0_faulty_gate2_x1) ==
#              r_0_faulty_gate3_z0) ==
#             (r_1_faulty_gate0_x0 == r_1_faulty_gate1_x1)) ==
#            r_1_faulty_gate2_z0)) ==
#          r_1_faulty_gate5_z0) ==
#         r_1_faulty_gate11_z1)) ==
#       (((((((((((r_0_faulty_gate0_x0 == r_0_faulty_gate1_x0) ==
#                 r_0_faulty_gate2_x1) ==
#                r_0_faulty_gate3_x1) ==
#               r_0_faulty_gate4_x0) ==
#              r_0_faulty_gate5_x1) ==
#             ((r_1_faulty_gate0_x0 == r_1_faulty_gate1_x1) ==
#              r_1_faulty_gate2_x1)) ==
#            r_1_faulty_gate3_x1) ==
#           r_1_faulty_gate6_x0) ==
#          r_1_faulty_gate9_x0) ==
#         ((r_1_faulty_gate12_x0 == r_1_faulty_gate13_x1) ==
#          r_1_faulty_gate14_x1)) ==
#        r_1_faulty_gate15_x1)) ==
#      (((((r_1_faulty_gate4_x0 == r_1_faulty_gate5_x1) ==
#          r_1_faulty_gate6_x1) ==
#         r_1_faulty_gate7_x1) ==
#        r_1_faulty_gate10_x0) ==
#       r_1_faulty_gate14_x0)),
#     Xor(Xor(Xor(Xor(Xor(Xor(Xor(False,
#                                 Xor(Xor(Xor(False,
#                                         r_1_faulty_gate4_x0),
#                                         r_1_faulty_gate5_x1),
#                                     r_1_faulty_gate6_x1)),
#                             r_1_faulty_gate7_x1),
#                         r_1_faulty_gate10_x0),
#                     Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(False,
#                                         False),
#                                         r_0_faulty_gate0_x1),
#                                         False),
#                                         r_1_faulty_gate0_x1),
#                                     False),
#                                 r_1_faulty_gate8_x1),
#                             Xor(Xor(False,
#                                     Xor(Xor(Xor(Xor(False,
#                                         r_1_faulty_gate0_x0),
#                                         Xor(Xor(Xor(Xor(False,
#                                         r_0_faulty_gate0_x0),
#                                         r_0_faulty_gate1_x0),
#                                         False),
#                                         r_0_faulty_gate2_z0)),
#                                         r_1_faulty_gate1_z0),
#                                         r_1_faulty_gate4_z1)),
#                                 r_1_faulty_gate12_z0)),
#                         r_1_faulty_gate13_z1)),
#                 r_1_faulty_gate14_z1),
#             Xor(Xor(Xor(False, r_1_faulty_gate8_x0),
#                     Xor(Xor(Xor(Xor(False,
#                                     r_1_faulty_gate4_x0),
#                                 r_1_faulty_gate5_x1),
#                             Xor(Xor(False,
#                                     r_0_faulty_gate5_z1),
#                                 r_1_faulty_gate3_z1)),
#                         r_1_faulty_gate6_z0)),
#                 r_1_faulty_gate9_z0)),
#         r_1_faulty_gate15_z0) ==
#     ((((((r_0_faulty_gate0_x1 == r_1_faulty_gate0_x1) ==
#          r_1_faulty_gate8_x1) ==
#         r_1_faulty_gate13_x0) ==
#        ((((r_1_faulty_gate0_x0 ==
#            ((r_0_faulty_gate0_x0 == r_0_faulty_gate1_x0) ==
#             r_0_faulty_gate2_z0)) ==
# ...
#
# ================================================================================

# %%
from proof_protocol import *
from protocol import *
from flag_analysis import *
from circuit_op import *
start_node, protocol = load_protocol("/Users/wuboris/Desktop/flag verification/protocols/chris_d_3_flag_protocol.json")

config = read_config("/Users/wuboris/Desktop/flag verification/[[9,1,3]]_surface_code_seq/[[9,1,3]]_chris_protocol_config.txt")
gen = load_symplectic_txt(str(config['stab_txt_path']))

init_state = new_clean_circuit_state(len(gen[0][0]))
t = 1




path = proof_protocol_boolean(protocol, start_node, init_state, config ,t)
# Out:
# Current node: root Instruction: flag_syndrome
# round: 0 node: root instr: flag_syndrome
# index: 0 name: cx qidxs: [9, 0]
# index: 1 name: cx qidxs: [9, 1]
# index: 2 name: cx qidxs: [10, 1]
# index: 3 name: cx qidxs: [10, 19]
# index: 4 name: cx qidxs: [10, 2]
# index: 5 name: cx qidxs: [10, 4]
# index: 6 name: cx qidxs: [10, 19]
# index: 7 name: cx qidxs: [10, 5]
# index: 8 name: cx qidxs: [11, 3]
# index: 9 name: cx qidxs: [11, 20]
# index: 10 name: cx qidxs: [11, 4]
# index: 11 name: cx qidxs: [11, 6]
# index: 12 name: cx qidxs: [11, 20]
# index: 13 name: cx qidxs: [11, 7]
# index: 14 name: cx qidxs: [12, 7]
# index: 15 name: cx qidxs: [12, 8]
# index: 16 name: cx qidxs: [0, 13]
# index: 17 name: cx qidxs: [17, 13]
# index: 18 name: cx qidxs: [1, 13]
# index: 19 name: cx qidxs: [3, 13]
# index: 20 name: cx qidxs: [17, 13]
# index: 21 name: cx qidxs: [4, 13]
# index: 22 name: cx qidxs: [2, 14]
# index: 23 name: cx qidxs: [5, 14]
# index: 24 name: cx qidxs: [3, 15]
# index: 25 name: cx qidxs: [6, 15]
# index: 26 name: cx qidxs: [4, 16]
# index: 27 name: cx qidxs: [18, 16]
# index: 28 name: cx qidxs: [5, 16]
# index: 29 name: cx qidxs: [7, 16]
# index: 30 name: cx qidxs: [18, 16]
# index: 31 name: cx qidxs: [8, 16]
# Current node: r_0_flagged Instruction: raw_syndrome
# round: 1 node: r_0_flagged instr: raw_syndrome
# index: 0 name: cx qidxs: [9, 0]
# index: 1 name: cx qidxs: [9, 1]
# index: 2 name: cx qidxs: [10, 1]
# index: 3 name: cx qidxs: [10, 2]
# index: 4 name: cx qidxs: [10, 4]
# index: 5 name: cx qidxs: [10, 5]
# index: 6 name: cx qidxs: [11, 3]
# index: 7 name: cx qidxs: [11, 4]
# index: 8 name: cx qidxs: [11, 6]
# index: 9 name: cx qidxs: [11, 7]
# index: 10 name: cx qidxs: [12, 7]
# index: 11 name: cx qidxs: [12, 8]
# index: 12 name: cx qidxs: [0, 13]
# index: 13 name: cx qidxs: [1, 13]
# index: 14 name: cx qidxs: [3, 13]
# index: 15 name: cx qidxs: [4, 13]
# index: 16 name: cx qidxs: [2, 14]
# index: 17 name: cx qidxs: [5, 14]
# index: 18 name: cx qidxs: [3, 15]
# index: 19 name: cx qidxs: [6, 15]
# index: 20 name: cx qidxs: [4, 16]
# index: 21 name: cx qidxs: [5, 16]
# index: 22 name: cx qidxs: [7, 16]
# index: 23 name: cx qidxs: [8, 16]
# Current node: ter_1 Instruction: LUT_s_0_f_0
# LUT LUT_s_0_f_0
# gen_syn: [('s', 0), ('f', 0)]
# len all paths: 1
# Path 1 data collected:
#   - Last data qubits: 9 qubits
#   - Rounds with anc/flag: 3
#   - Path conditions: 3
# Current node: r_0_not_flagged Instruction: flag_syndrome
# round: 1 node: r_0_not_flagged instr: flag_syndrome
# index: 0 name: cx qidxs: [9, 0]
# index: 1 name: cx qidxs: [9, 1]
# index: 2 name: cx qidxs: [10, 1]
# index: 3 name: cx qidxs: [10, 19]
# index: 4 name: cx qidxs: [10, 2]
# index: 5 name: cx qidxs: [10, 4]
# index: 6 name: cx qidxs: [10, 19]
# index: 7 name: cx qidxs: [10, 5]
# index: 8 name: cx qidxs: [11, 3]
# index: 9 name: cx qidxs: [11, 20]
# index: 10 name: cx qidxs: [11, 4]
# index: 11 name: cx qidxs: [11, 6]
# index: 12 name: cx qidxs: [11, 20]
# index: 13 name: cx qidxs: [11, 7]
# index: 14 name: cx qidxs: [12, 7]
# index: 15 name: cx qidxs: [12, 8]
# index: 16 name: cx qidxs: [0, 13]
# index: 17 name: cx qidxs: [17, 13]
# index: 18 name: cx qidxs: [1, 13]
# index: 19 name: cx qidxs: [3, 13]
# index: 20 name: cx qidxs: [17, 13]
# index: 21 name: cx qidxs: [4, 13]
# index: 22 name: cx qidxs: [2, 14]
# index: 23 name: cx qidxs: [5, 14]
# index: 24 name: cx qidxs: [3, 15]
# index: 25 name: cx qidxs: [6, 15]
# index: 26 name: cx qidxs: [4, 16]
# index: 27 name: cx qidxs: [18, 16]
# index: 28 name: cx qidxs: [5, 16]
# index: 29 name: cx qidxs: [7, 16]
# index: 30 name: cx qidxs: [18, 16]
# index: 31 name: cx qidxs: [8, 16]
# Current node: r_1_flagged Instruction: raw_syndrome
# round: 2 node: r_1_flagged instr: raw_syndrome
# index: 0 name: cx qidxs: [9, 0]
# index: 1 name: cx qidxs: [9, 1]
# index: 2 name: cx qidxs: [10, 1]
# index: 3 name: cx qidxs: [10, 2]
# index: 4 name: cx qidxs: [10, 4]
# index: 5 name: cx qidxs: [10, 5]
# index: 6 name: cx qidxs: [11, 3]
# index: 7 name: cx qidxs: [11, 4]
# index: 8 name: cx qidxs: [11, 6]
# index: 9 name: cx qidxs: [11, 7]
# index: 10 name: cx qidxs: [12, 7]
# index: 11 name: cx qidxs: [12, 8]
# index: 12 name: cx qidxs: [0, 13]
# index: 13 name: cx qidxs: [1, 13]
# index: 14 name: cx qidxs: [3, 13]
# index: 15 name: cx qidxs: [4, 13]
# index: 16 name: cx qidxs: [2, 14]
# index: 17 name: cx qidxs: [5, 14]
# index: 18 name: cx qidxs: [3, 15]
# index: 19 name: cx qidxs: [6, 15]
# index: 20 name: cx qidxs: [4, 16]
# index: 21 name: cx qidxs: [5, 16]
# index: 22 name: cx qidxs: [7, 16]
# index: 23 name: cx qidxs: [8, 16]
# Current node: ter_2 Instruction: LUT_s_0_f_0_s_1_f_1
# LUT LUT_s_0_f_0_s_1_f_1
# gen_syn: [('s', 0), ('f', 0), ('s', 1), ('f', 1)]
# len all paths: 2
# Path 2 data collected:
#   - Last data qubits: 9 qubits
#   - Rounds with anc/flag: 4
#   - Path conditions: 4
# Current node: r_1_not_flagged_and_s1_neq_s0 Instruction: raw_syndrome
# round: 2 node: r_1_not_flagged_and_s1_neq_s0 instr: raw_syndrome
# index: 0 name: cx qidxs: [9, 0]
# index: 1 name: cx qidxs: [9, 1]
# index: 2 name: cx qidxs: [10, 1]
# index: 3 name: cx qidxs: [10, 2]
# index: 4 name: cx qidxs: [10, 4]
# index: 5 name: cx qidxs: [10, 5]
# index: 6 name: cx qidxs: [11, 3]
# index: 7 name: cx qidxs: [11, 4]
# index: 8 name: cx qidxs: [11, 6]
# index: 9 name: cx qidxs: [11, 7]
# index: 10 name: cx qidxs: [12, 7]
# index: 11 name: cx qidxs: [12, 8]
# index: 12 name: cx qidxs: [0, 13]
# index: 13 name: cx qidxs: [1, 13]
# index: 14 name: cx qidxs: [3, 13]
# index: 15 name: cx qidxs: [4, 13]
# index: 16 name: cx qidxs: [2, 14]
# index: 17 name: cx qidxs: [5, 14]
# index: 18 name: cx qidxs: [3, 15]
# index: 19 name: cx qidxs: [6, 15]
# index: 20 name: cx qidxs: [4, 16]
# index: 21 name: cx qidxs: [5, 16]
# index: 22 name: cx qidxs: [7, 16]
# index: 23 name: cx qidxs: [8, 16]
# Current node: ter_3 Instruction: LUT_s_0_f_0_s_1_f_1
# LUT LUT_s_0_f_0_s_1_f_1
# gen_syn: [('s', 0), ('f', 0), ('s', 1), ('f', 1)]
# len all paths: 3
# Path 3 data collected:
#   - Last data qubits: 9 qubits
#   - Rounds with anc/flag: 4
#   - Path conditions: 4
# Current node: r_1_not_flagged_and_s1_eq_s0 Instruction: raw_syndrome
# round: 2 node: r_1_not_flagged_and_s1_eq_s0 instr: raw_syndrome
# index: 0 name: cx qidxs: [9, 0]
# index: 1 name: cx qidxs: [9, 1]
# index: 2 name: cx qidxs: [10, 1]
# index: 3 name: cx qidxs: [10, 2]
# index: 4 name: cx qidxs: [10, 4]
# index: 5 name: cx qidxs: [10, 5]
# index: 6 name: cx qidxs: [11, 3]
# index: 7 name: cx qidxs: [11, 4]
# index: 8 name: cx qidxs: [11, 6]
# index: 9 name: cx qidxs: [11, 7]
# index: 10 name: cx qidxs: [12, 7]
# index: 11 name: cx qidxs: [12, 8]
# index: 12 name: cx qidxs: [0, 13]
# index: 13 name: cx qidxs: [1, 13]
# index: 14 name: cx qidxs: [3, 13]
# index: 15 name: cx qidxs: [4, 13]
# index: 16 name: cx qidxs: [2, 14]
# index: 17 name: cx qidxs: [5, 14]
# index: 18 name: cx qidxs: [3, 15]
# index: 19 name: cx qidxs: [6, 15]
# index: 20 name: cx qidxs: [4, 16]
# index: 21 name: cx qidxs: [5, 16]
# index: 22 name: cx qidxs: [7, 16]
# index: 23 name: cx qidxs: [8, 16]
# Current node: ter_4 Instruction: LUT_s_0_f_0_s_1_f_1
# LUT LUT_s_0_f_0_s_1_f_1
# gen_syn: [('s', 0), ('f', 0), ('s', 1), ('f', 1)]
# len all paths: 4
# Path 4 data collected:
#   - Last data qubits: 9 qubits
#   - Rounds with anc/flag: 4
#   - Path conditions: 4
#
# ================================================================================
# COLLECTED DATA FROM 4 PATHS
# ================================================================================
#
# --- PATH 1 ---
#
# Measured syndrome:
#    [Xor(Xor(Xor(Xor(False,
#                 Xor(Xor(Xor(False, r_0_faulty_gate0_z1),
#                         False),
#                     r_0_faulty_gate16_z0)),
#             r_1_faulty_gate0_z0),
#         Xor(Xor(Xor(Xor(False, r_0_faulty_gate1_z1),
#                     r_0_faulty_gate2_z1),
#                 Xor(Xor(False, r_0_faulty_gate16_z1),
#                     r_0_faulty_gate17_z1)),
#             r_0_faulty_gate18_z0)),
#     r_1_faulty_gate1_z0), Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(False,
#                                 Xor(Xor(Xor(Xor(Xor(False,
#                                         r_0_faulty_gate1_z1),
#                                         r_0_faulty_gate2_z1),
#                                         Xor(Xor(False,
#                                         r_0_faulty_gate16_z1),
#                                         r_0_faulty_gate17_z1)),
#                                         r_0_faulty_gate18_z0),
#                                     r_1_faulty_gate1_z1)),
#                             r_1_faulty_gate2_z0),
#                         Xor(Xor(Xor(False,
#                                     r_0_faulty_gate4_z1),
#                                 False),
#                             r_0_faulty_gate22_z0)),
#                     r_1_faulty_gate3_z0),
#                 Xor(Xor(Xor(Xor(Xor(Xor(False,
#                                         r_0_faulty_gate5_z1),
#                                     r_0_faulty_gate10_z1),
#                                 Xor(Xor(Xor(Xor(Xor(False,
#                                         r_0_faulty_gate16_z1),
#                                         r_0_faulty_gate17_z1),
#                                         r_0_faulty_gate18_z1),
#                                         r_0_faulty_gate19_z1),
#                                     r_0_faulty_gate20_z1)),
#                             r_0_faulty_gate21_z0),
#                         False),
#                     r_0_faulty_gate26_z0)),
#             r_1_faulty_gate4_z0),
#         Xor(Xor(Xor(Xor(Xor(False, r_0_faulty_gate7_z1),
#                         Xor(False, r_0_faulty_gate22_z1)),
#                     r_0_faulty_gate23_z0),
#                 Xor(Xor(False, r_0_faulty_gate26_z1),
#                     r_0_faulty_gate27_z1)),
#             r_0_faulty_gate28_z0)),
#     r_1_faulty_gate5_z0), Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(False,
#                                 Xor(Xor(Xor(Xor(Xor(False,
#                                         r_0_faulty_gate8_z1),
#                                         Xor(Xor(Xor(False,
#                                         r_0_faulty_gate16_z1),
#                                         r_0_faulty_gate17_z1),
#                                         r_0_faulty_gate18_z1)),
#                                         r_0_faulty_gate19_z0),
#                                         False),
#                                     r_0_faulty_gate24_z0)),
#                             r_1_faulty_gate6_z0),
#                         Xor(Xor(Xor(Xor(Xor(Xor(Xor(False,
#                                         r_0_faulty_gate5_z1),
#                                         r_0_faulty_gate10_z1),
#                                         Xor(Xor(Xor(Xor(Xor(False,
#                                         r_0_faulty_gate16_z1),
#                                         r_0_faulty_gate17_z1),
#                                         r_0_faulty_gate18_z1),
#                                         r_0_faulty_gate19_z1),
#                                         r_0_faulty_gate20_z1)),
#                                         r_0_faulty_gate21_z0),
#                                     False),
#                                 r_0_faulty_gate26_z0),
#                             r_1_faulty_gate4_z1)),
#                     r_1_faulty_gate7_z0),
#                 Xor(Xor(Xor(False, r_0_faulty_gate11_z1),
#                         Xor(False, r_0_faulty_gate24_z1)),
#                     r_0_faulty_gate25_z0)),
#             r_1_faulty_gate8_z0),
#         Xor(Xor(Xor(Xor(False, r_0_faulty_gate13_z1),
#                     r_0_faulty_gate14_z1),
#                 Xor(Xor(Xor(False, r_0_faulty_gate26_z1),
#                         r_0_faulty_gate27_z1),
#                     r_0_faulty_gate28_z1)),
#             r_0_faulty_gate29_z0)),
#     r_1_faulty_gate9_z0), Xor(Xor(Xor(Xor(False,
#                 Xor(Xor(Xor(Xor(Xor(False,
#                                     r_0_faulty_gate13_z1),
#                                 r_0_faulty_gate14_z1),
#                             Xor(Xor(Xor(False,
#                                         r_0_faulty_gate26_z1),
#                                     r_0_faulty_gate27_z1),
#                                 r_0_faulty_gate28_z1)),
#                         r_0_faulty_gate29_z0),
#                     r_1_faulty_gate9_z1)),
#             r_1_faulty_gate10_z0),
#         Xor(Xor(Xor(False, r_0_faulty_gate15_z1),
#                 Xor(Xor(Xor(Xor(Xor(False,
#                                     r_0_faulty_gate26_z1),
#                                 r_0_faulty_gate27_z1),
#                             r_0_faulty_gate28_z1),
#                         r_0_faulty_gate29_z1),
#                     r_0_faulty_gate30_z1)),
#             r_0_faulty_gate31_z0)),
#     r_1_faulty_gate11_z0), Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(False,
#                                 Xor(Xor(Xor(Xor(Xor(False,
#                                         False),
#                                         r_0_faulty_gate0_x1),
#                                         r_0_faulty_gate16_x0),
#                                         False),
#                                     r_1_faulty_gate0_x1)),
#                             r_1_faulty_gate12_x1),
#                         Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(False,
#                                         Xor(False,
#                                         r_0_faulty_gate0_x0)),
#                                         r_0_faulty_gate1_x1),
#                                         False),
#                                         r_0_faulty_gate2_x1),
#                                         r_0_faulty_gate18_x0),
#                                         Xor(False,
#                                         r_1_faulty_gate0_x0)),
#                                     r_1_faulty_gate1_x1),
#                                 False),
#                             r_1_faulty_gate2_x1)),
#                     r_1_faulty_gate13_x1),
#                 Xor(Xor(Xor(Xor(Xor(Xor(False, False),
#                                     r_0_faulty_gate8_x1),
#                                 r_0_faulty_gate19_x0),
#                             r_0_faulty_gate24_x0),
#                         False),
#                     r_1_faulty_gate6_x1)),
#             r_1_faulty_gate14_x1),
#         Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(False,
#                                         Xor(Xor(Xor(False,
#                                         r_0_faulty_gate2_x0),
#                                         r_0_faulty_gate3_x0),
#                                         r_0_faulty_gate4_x0)),
#                                         r_0_faulty_gate5_x1),
#                                         Xor(Xor(False,
#                                         r_0_faulty_gate8_x0),
#                                         r_0_faulty_gate9_x0)),
#                                     r_0_faulty_gate10_x1),
#                                 r_0_faulty_gate21_x0),
#                             r_0_faulty_gate26_x0),
#                         Xor(Xor(False, r_1_faulty_gate2_x0),
#                             r_1_faulty_gate3_x0)),
#                     r_1_faulty_gate4_x1),
#                 Xor(False, r_1_faulty_gate6_x0)),
#             r_1_faulty_gate7_x1)),
#     r_1_faulty_gate15_x1), Xor(Xor(Xor(Xor(False,
#                 Xor(Xor(Xor(Xor(Xor(False,
#                                     Xor(Xor(False,
#                                         r_0_faulty_gate2_x0),
#                                         r_0_faulty_gate3_x0)),
#                                 r_0_faulty_gate4_x1),
#                             r_0_faulty_gate22_x0),
#                         Xor(False, r_1_faulty_gate2_x0)),
#                     r_1_faulty_gate3_x1)),
#             r_1_faulty_gate16_x1),
#         Xor(Xor(Xor(Xor(Xor(Xor(False,
#                                 Xor(Xor(Xor(Xor(Xor(False,
#                                         r_0_faulty_gate2_x0),
#                                         r_0_faulty_gate3_x0),
#                                         r_0_faulty_gate4_x0),
#                                         r_0_faulty_gate5_x0),
#                                     r_0_faulty_gate6_x0)),
#                             r_0_faulty_gate7_x1),
#                         r_0_faulty_gate23_x0),
#                     r_0_faulty_gate28_x0),
#                 Xor(Xor(Xor(False, r_1_faulty_gate2_x0),
#                         r_1_faulty_gate3_x0),
#                     r_1_faulty_gate4_x0)),
#             r_1_faulty_gate5_x1)),
#     r_1_faulty_gate17_x1), Xor(Xor(Xor(Xor(False,
#                 Xor(Xor(Xor(Xor(Xor(Xor(Xor(False, False),
#                                         r_0_faulty_gate8_x1),
#                                     r_0_faulty_gate19_x0),
#                                 r_0_faulty_gate24_x0),
#                             False),
#                         r_1_faulty_gate6_x1),
#                     r_1_faulty_gate14_x0)),
#             r_1_faulty_gate18_x1),
#         Xor(Xor(Xor(Xor(Xor(False,
#                             Xor(Xor(Xor(False,
#                                         r_0_faulty_gate8_x0),
#                                     r_0_faulty_gate9_x0),
#                                 r_0_faulty_gate10_x0)),
#                         r_0_faulty_gate11_x1),
#                     r_0_faulty_gate25_x0),
#                 Xor(Xor(False, r_1_faulty_gate6_x0),
#                     r_1_faulty_gate7_x0)),
#             r_1_faulty_gate8_x1)),
#     r_1_faulty_gate19_x1), Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(False,
#                                 Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(False,
#                                         Xor(Xor(..., ...),
#                                         r_0_faulty_gate4_x0)),
#                                         r_0_faulty_gate5_x1),
#                                         Xor(Xor(False,
#                                         r_0_faulty_gate8_x0),
#                                         r_0_faulty_gate9_x0)),
#                                         r_0_faulty_gate10_x1),
#                                         r_0_faulty_gate21_x0),
#                                         r_0_faulty_gate26_x0),
#                                         Xor(Xor(False,
#                                         r_1_faulty_gate2_x0),
#                                         r_1_faulty_gate3_x0)),
#                                         r_1_faulty_gate4_x1),
#                                         Xor(False,
#                                         r_1_faulty_gate6_x0)),
#                                         r_1_faulty_gate7_x1),
#                                     r_1_faulty_gate15_x0)),
#                             r_1_faulty_gate20_x1),
#                         Xor(Xor(Xor(Xor(Xor(Xor(Xor(False,
#                                         Xor(Xor(Xor(Xor(Xor(False,
#                                         r_0_faulty_gate2_x0),
#                                         r_0_faulty_gate3_x0),
#                                         r_0_faulty_gate4_x0),
#                                         r_0_faulty_gate5_x0),
#                                         r_0_faulty_gate6_x0)),
#                                         r_0_faulty_gate7_x1),
#                                         r_0_faulty_gate23_x0),
#                                         r_0_faulty_gate28_x0),
#                                     Xor(Xor(Xor(False,
#                                         r_1_faulty_gate2_x0),
#                                         r_1_faulty_gate3_x0),
#                                         r_1_faulty_gate4_x0)),
#                                 r_1_faulty_gate5_x1),
#                             r_1_faulty_gate17_x0)),
#                     r_1_faulty_gate21_x1),
#                 Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(False,
#                                         Xor(Xor(Xor(Xor(Xor(False,
#                                         r_0_faulty_gate8_x0),
#                                         r_0_faulty_gate9_x0),
#                                         r_0_faulty_gate10_x0),
#                                         r_0_faulty_gate11_x0),
#                                         r_0_faulty_gate12_x0)),
#                                         r_0_faulty_gate13_x1),
#                                         False),
#                                         r_0_faulty_gate14_x1),
#                                     r_0_faulty_gate29_x0),
#                                 Xor(Xor(Xor(False,
#                                         r_1_faulty_gate6_x0),
#                                         r_1_faulty_gate7_x0),
#                                     r_1_faulty_gate8_x0)),
#                             r_1_faulty_gate9_x1),
#                         False),
#                     r_1_faulty_gate10_x1)),
#             r_1_faulty_gate22_x1),
#         Xor(Xor(Xor(Xor(Xor(False,
#                             Xor(False, r_0_faulty_gate14_x0)),
#                         r_0_faulty_gate15_x1),
#                     r_0_faulty_gate31_x0),
#                 Xor(False, r_1_faulty_gate10_x0)),
#             r_1_faulty_gate11_x1)),
#     r_1_faulty_gate23_x1)]
#
# Commutation syndrome:
#    [(((r_0_faulty_gate0_z1 == r_0_faulty_gate16_z0) ==
#   r_1_faulty_gate0_z1) ==
#  r_1_faulty_gate12_z0) ==
# (((((((r_0_faulty_gate16_z1 == r_0_faulty_gate17_z1) ==
#       (r_0_faulty_gate1_z1 == r_0_faulty_gate2_z1)) ==
#      r_0_faulty_gate18_z0) ==
#     r_1_faulty_gate1_z1) ==
#    r_1_faulty_gate2_z1) ==
#   r_1_faulty_gate12_z1) ==
#  r_1_faulty_gate13_z0), Not((((((((((r_0_faulty_gate16_z1 == r_0_faulty_gate17_z1) ==
#             (r_0_faulty_gate1_z1 == r_0_faulty_gate2_z1)) ==
#            r_0_faulty_gate18_z0) ==
#           r_1_faulty_gate1_z1) ==
#          r_1_faulty_gate2_z1) ==
#         r_1_faulty_gate12_z1) ==
#        r_1_faulty_gate13_z0) ==
#       (((r_0_faulty_gate4_z1 == r_0_faulty_gate22_z0) ==
#         r_1_faulty_gate3_z1) ==
#        r_1_faulty_gate16_z0)) ==
#      (((((((((r_0_faulty_gate5_z1 == r_0_faulty_gate10_z1) ==
#              ((((r_0_faulty_gate16_z1 ==
#                  r_0_faulty_gate17_z1) ==
#                 r_0_faulty_gate18_z1) ==
#                r_0_faulty_gate19_z1) ==
#               r_0_faulty_gate20_z1)) ==
#             r_0_faulty_gate21_z0) ==
#            r_0_faulty_gate26_z0) ==
#           r_1_faulty_gate4_z1) ==
#          r_1_faulty_gate7_z1) ==
#         ((r_1_faulty_gate12_z1 == r_1_faulty_gate13_z1) ==
#          r_1_faulty_gate14_z1)) ==
#        r_1_faulty_gate15_z0) ==
#       r_1_faulty_gate20_z0)) ==
#     (((((((((r_0_faulty_gate7_z1 == r_0_faulty_gate22_z1) ==
#             r_0_faulty_gate23_z0) ==
#            (r_0_faulty_gate26_z1 == r_0_faulty_gate27_z1)) ==
#           r_0_faulty_gate28_z0) ==
#          r_1_faulty_gate5_z1) ==
#         r_1_faulty_gate16_z1) ==
#        r_1_faulty_gate17_z0) ==
#       r_1_faulty_gate20_z1) ==
#      r_1_faulty_gate21_z0)), Not((((((((((r_0_faulty_gate8_z1 ==
#              ((r_0_faulty_gate16_z1 == r_0_faulty_gate17_z1) ==
#               r_0_faulty_gate18_z1)) ==
#             r_0_faulty_gate19_z0) ==
#            r_0_faulty_gate24_z0) ==
#           r_1_faulty_gate6_z1) ==
#          (r_1_faulty_gate12_z1 == r_1_faulty_gate13_z1)) ==
#         r_1_faulty_gate14_z0) ==
#        r_1_faulty_gate18_z0) ==
#       (((((((((r_0_faulty_gate5_z1 == r_0_faulty_gate10_z1) ==
#               ((((r_0_faulty_gate16_z1 ==
#                   r_0_faulty_gate17_z1) ==
#                  r_0_faulty_gate18_z1) ==
#                 r_0_faulty_gate19_z1) ==
#                r_0_faulty_gate20_z1)) ==
#              r_0_faulty_gate21_z0) ==
#             r_0_faulty_gate26_z0) ==
#            r_1_faulty_gate4_z1) ==
#           r_1_faulty_gate7_z1) ==
#          ((r_1_faulty_gate12_z1 == r_1_faulty_gate13_z1) ==
#           r_1_faulty_gate14_z1)) ==
#         r_1_faulty_gate15_z0) ==
#        r_1_faulty_gate20_z0)) ==
#      (((((r_0_faulty_gate11_z1 == r_0_faulty_gate24_z1) ==
#          r_0_faulty_gate25_z0) ==
#         r_1_faulty_gate8_z1) ==
#        r_1_faulty_gate18_z1) ==
#       r_1_faulty_gate19_z0)) ==
#     (((r_1_faulty_gate20_z1 == r_1_faulty_gate21_z1) ==
#       (((((r_0_faulty_gate13_z1 == r_0_faulty_gate14_z1) ==
#           ((r_0_faulty_gate26_z1 == r_0_faulty_gate27_z1) ==
#            r_0_faulty_gate28_z1)) ==
#          r_0_faulty_gate29_z0) ==
#         r_1_faulty_gate9_z1) ==
#        r_1_faulty_gate10_z1)) ==
#      r_1_faulty_gate22_z0)), (((r_1_faulty_gate20_z1 == r_1_faulty_gate21_z1) ==
#   (((((r_0_faulty_gate13_z1 == r_0_faulty_gate14_z1) ==
#       ((r_0_faulty_gate26_z1 == r_0_faulty_gate27_z1) ==
#        r_0_faulty_gate28_z1)) ==
#      r_0_faulty_gate29_z0) ==
#     r_1_faulty_gate9_z1) ==
#    r_1_faulty_gate10_z1)) ==
#  r_1_faulty_gate22_z0) ==
# (((((r_0_faulty_gate15_z1 ==
#      ((((r_0_faulty_gate26_z1 == r_0_faulty_gate27_z1) ==
#         r_0_faulty_gate28_z1) ==
#        r_0_faulty_gate29_z1) ==
#       r_0_faulty_gate30_z1)) ==
#     r_0_faulty_gate31_z0) ==
#    r_1_faulty_gate11_z1) ==
#   ((r_1_faulty_gate20_z1 == r_1_faulty_gate21_z1) ==
#    r_1_faulty_gate22_z1)) ==
#  r_1_faulty_gate23_z0), Not((((((((((((r_0_faulty_gate8_x0 == r_0_faulty_gate9_x0) ==
#               (((r_0_faulty_gate2_x0 == r_0_faulty_gate3_x0) ==
#                 r_0_faulty_gate4_x0) ==
#                r_0_faulty_gate5_x1)) ==
#              r_0_faulty_gate10_x1) ==
#             r_0_faulty_gate21_x0) ==
#            r_0_faulty_gate26_x0) ==
#           (r_1_faulty_gate2_x0 == r_1_faulty_gate3_x0)) ==
#          r_1_faulty_gate4_x1) ==
#         r_1_faulty_gate6_x0) ==
#        r_1_faulty_gate7_x1) ==
#       r_1_faulty_gate15_x0) ==
#      r_1_faulty_gate20_x0) ==
#     ((((((r_0_faulty_gate8_x1 == r_0_faulty_gate19_x0) ==
#          r_0_faulty_gate24_x0) ==
#         r_1_faulty_gate6_x1) ==
#        r_1_faulty_gate14_x0) ==
#       r_1_faulty_gate18_x0) ==
#      ((((((((r_0_faulty_gate0_x0 == r_0_faulty_gate1_x1) ==
#             r_0_faulty_gate2_x1) ==
#            r_0_faulty_gate18_x0) ==
#           r_1_faulty_gate0_x0) ==
#          r_1_faulty_gate1_x1) ==
#         r_1_faulty_gate2_x1) ==
#        r_1_faulty_gate13_x0) ==
#       (((r_0_faulty_gate0_x1 == r_0_faulty_gate16_x0) ==
#         r_1_faulty_gate0_x1) ==
#        r_1_faulty_gate12_x0)))), ((((((r_0_faulty_gate2_x0 == r_0_faulty_gate3_x0) ==
#      r_0_faulty_gate4_x1) ==
#     r_0_faulty_gate22_x0) ==
#    r_1_faulty_gate2_x0) ==
#   r_1_faulty_gate3_x1) ==
#  r_1_faulty_gate16_x0) ==
# (((((((((((r_0_faulty_gate2_x0 == r_0_faulty_gate3_x0) ==
#           r_0_faulty_gate4_x0) ==
#          r_0_faulty_gate5_x0) ==
#         r_0_faulty_gate6_x0) ==
#        r_0_faulty_gate7_x1) ==
#       r_0_faulty_gate23_x0) ==
#      r_0_faulty_gate28_x0) ==
#     ((r_1_faulty_gate2_x0 == r_1_faulty_gate3_x0) ==
#      r_1_faulty_gate4_x0)) ==
#    r_1_faulty_gate5_x1) ==
#   r_1_faulty_gate17_x0) ==
#  r_1_faulty_gate21_x0), (((((r_0_faulty_gate8_x1 == r_0_faulty_gate19_x0) ==
#     r_0_faulty_gate24_x0) ==
#    r_1_faulty_gate6_x1) ==
#   r_1_faulty_gate14_x0) ==
#  r_1_faulty_gate18_x0) ==
# (((((((r_0_faulty_gate8_x0 == r_0_faulty_gate9_x0) ==
#       r_0_faulty_gate10_x0) ==
#      r_0_faulty_gate11_x1) ==
#     r_0_faulty_gate25_x0) ==
#    (r_1_faulty_gate6_x0 == r_1_faulty_gate7_x0)) ==
#   r_1_faulty_gate8_x1) ==
#  r_1_faulty_gate19_x0), Not((((((r_0_faulty_gate14_x0 == r_0_faulty_gate15_x1) ==
#         r_0_faulty_gate31_x0) ==
#        r_1_faulty_gate10_x0) ==
#       r_1_faulty_gate11_x1) ==
#      r_1_faulty_gate23_x0) ==
#     ((((((((((((r_0_faulty_gate8_x0 == r_0_faulty_gate9_x0) ==
#                r_0_faulty_gate10_x0) ==
#               r_0_faulty_gate11_x0) ==
#              r_0_faulty_gate12_x0) ==
#             r_0_faulty_gate13_x1) ==
#            r_0_faulty_gate14_x1) ==
#           r_0_faulty_gate29_x0) ==
#          ((r_1_faulty_gate6_x0 == r_1_faulty_gate7_x0) ==
#           r_1_faulty_gate8_x0)) ==
#         r_1_faulty_gate9_x1) ==
#        r_1_faulty_gate10_x1) ==
#       r_1_faulty_gate22_x0) ==
#      ((((((((((((r_0_faulty_gate2_x0 == r_0_faulty_gate3_x0) ==
#                 r_0_faulty_gate4_x0) ==
#                r_0_faulty_gate5_x0) ==
#               r_0_faulty_gate6_x0) ==
#              r_0_faulty_gate7_x1) ==
#             r_0_faulty_gate23_x0) ==
#            r_0_faulty_gate28_x0) ==
#           ((r_1_faulty_gate2_x0 == r_1_faulty_gate3_x0) ==
#            r_1_faulty_gate4_x0)) ==
#          r_1_faulty_gate5_x1) ==
#         r_1_faulty_gate17_x0) ==
#        r_1_faulty_gate21_x0) ==
#       (((((((((((r_0_faulty_gate8_x0 == r_0_faulty_gate9_x0) ==
#                 (((r_0_faulty_gate2_x0 ==
#                    r_0_faulty_gate3_x0) ==
#                   r_0_faulty_gate4_x0) ==
#                  r_0_faulty_gate5_x1)) ==
#                r_0_faulty_gate10_x1) ==
#               r_0_faulty_gate21_x0) ==
#              r_0_faulty_gate26_x0) ==
#             (r_1_faulty_gate2_x0 == r_1_faulty_gate3_x0)) ==
#            r_1_faulty_gate4_x1) ==
#           r_1_faulty_gate6_x0) ==
#          r_1_faulty_gate7_x1) ==
#         r_1_faulty_gate15_x0) ==
#        r_1_faulty_gate20_x0))))]
#
# Syndrome equality constraint:
#    And(Xor(Xor(Xor(Xor(False,
#                     Xor(Xor(Xor(False, r_0_faulty_gate0_z1),
#                             False),
#                         r_0_faulty_gate16_z0)),
#                 r_1_faulty_gate0_z0),
#             Xor(Xor(Xor(Xor(False, r_0_faulty_gate1_z1),
#                         r_0_faulty_gate2_z1),
#                     Xor(Xor(False, r_0_faulty_gate16_z1),
#                         r_0_faulty_gate17_z1)),
#                 r_0_faulty_gate18_z0)),
#         r_1_faulty_gate1_z0) ==
#     ((((r_0_faulty_gate0_z1 == r_0_faulty_gate16_z0) ==
#        r_1_faulty_gate0_z1) ==
#       r_1_faulty_gate12_z0) ==
#      (((((((r_0_faulty_gate16_z1 == r_0_faulty_gate17_z1) ==
#            (r_0_faulty_gate1_z1 == r_0_faulty_gate2_z1)) ==
#           r_0_faulty_gate18_z0) ==
#          r_1_faulty_gate1_z1) ==
#         r_1_faulty_gate2_z1) ==
#        r_1_faulty_gate12_z1) ==
#       r_1_faulty_gate13_z0)),
#     Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(False,
#                                     Xor(Xor(Xor(Xor(Xor(False,
#                                         r_0_faulty_gate1_z1),
#                                         r_0_faulty_gate2_z1),
#                                         Xor(Xor(False,
#                                         r_0_faulty_gate16_z1),
#                                         r_0_faulty_gate17_z1)),
#                                         r_0_faulty_gate18_z0),
#                                         r_1_faulty_gate1_z1)),
#                                 r_1_faulty_gate2_z0),
#                             Xor(Xor(Xor(False,
#                                         r_0_faulty_gate4_z1),
#                                     False),
#                                 r_0_faulty_gate22_z0)),
#                         r_1_faulty_gate3_z0),
#                     Xor(Xor(Xor(Xor(Xor(Xor(False,
#                                         r_0_faulty_gate5_z1),
#                                         r_0_faulty_gate10_z1),
#                                     Xor(Xor(Xor(Xor(Xor(False,
#                                         r_0_faulty_gate16_z1),
#                                         r_0_faulty_gate17_z1),
#                                         r_0_faulty_gate18_z1),
#                                         r_0_faulty_gate19_z1),
#                                         r_0_faulty_gate20_z1)),
#                                 r_0_faulty_gate21_z0),
#                             False),
#                         r_0_faulty_gate26_z0)),
#                 r_1_faulty_gate4_z0),
#             Xor(Xor(Xor(Xor(Xor(False, r_0_faulty_gate7_z1),
#                             Xor(False, r_0_faulty_gate22_z1)),
#                         r_0_faulty_gate23_z0),
#                     Xor(Xor(False, r_0_faulty_gate26_z1),
#                         r_0_faulty_gate27_z1)),
#                 r_0_faulty_gate28_z0)),
#         r_1_faulty_gate5_z0) ==
#     Not((((((((((r_0_faulty_gate16_z1 ==
#                  r_0_faulty_gate17_z1) ==
#                 (r_0_faulty_gate1_z1 == r_0_faulty_gate2_z1)) ==
#                r_0_faulty_gate18_z0) ==
#               r_1_faulty_gate1_z1) ==
#              r_1_faulty_gate2_z1) ==
#             r_1_faulty_gate12_z1) ==
#            r_1_faulty_gate13_z0) ==
#           (((r_0_faulty_gate4_z1 == r_0_faulty_gate22_z0) ==
#             r_1_faulty_gate3_z1) ==
#            r_1_faulty_gate16_z0)) ==
#          (((((((((r_0_faulty_gate5_z1 ==
#                   r_0_faulty_gate10_z1) ==
#                  ((((r_0_faulty_gate16_z1 ==
#                      r_0_faulty_gate17_z1) ==
#                     r_0_faulty_gate18_z1) ==
#                    r_0_faulty_gate19_z1) ==
#                   r_0_faulty_gate20_z1)) ==
#                 r_0_faulty_gate21_z0) ==
#                r_0_faulty_gate26_z0) ==
#               r_1_faulty_gate4_z1) ==
#              r_1_faulty_gate7_z1) ==
#             ((r_1_faulty_gate12_z1 == r_1_faulty_gate13_z1) ==
#              r_1_faulty_gate14_z1)) ==
#            r_1_faulty_gate15_z0) ==
#           r_1_faulty_gate20_z0)) ==
#         (((((((((r_0_faulty_gate7_z1 == r_0_faulty_gate22_z1) ==
#                 r_0_faulty_gate23_z0) ==
#                (r_0_faulty_gate26_z1 == r_0_faulty_gate27_z1)) ==
#               r_0_faulty_gate28_z0) ==
#              r_1_faulty_gate5_z1) ==
#             r_1_faulty_gate16_z1) ==
#            r_1_faulty_gate17_z0) ==
#           r_1_faulty_gate20_z1) ==
#          r_1_faulty_gate21_z0)),
#     Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(False,
#                                     Xor(Xor(Xor(Xor(Xor(False,
#                                         r_0_faulty_gate8_z1),
#                                         Xor(Xor(Xor(False,
#                                         r_0_faulty_gate16_z1),
#                                         r_0_faulty_gate17_z1),
#                                         r_0_faulty_gate18_z1)),
#                                         r_0_faulty_gate19_z0),
#                                         False),
#                                         r_0_faulty_gate24_z0)),
#                                 r_1_faulty_gate6_z0),
#                             Xor(Xor(Xor(Xor(Xor(Xor(Xor(False,
#                                         r_0_faulty_gate5_z1),
#                                         r_0_faulty_gate10_z1),
#                                         Xor(Xor(Xor(Xor(Xor(False,
#                                         r_0_faulty_gate16_z1),
#                                         r_0_faulty_gate17_z1),
#                                         r_0_faulty_gate18_z1),
#                                         r_0_faulty_gate19_z1),
#                                         r_0_faulty_gate20_z1)),
#                                         r_0_faulty_gate21_z0),
#                                         False),
#                                     r_0_faulty_gate26_z0),
#                                 r_1_faulty_gate4_z1)),
#                         r_1_faulty_gate7_z0),
#                     Xor(Xor(Xor(False, r_0_faulty_gate11_z1),
#                             Xor(False, r_0_faulty_gate24_z1)),
#                         r_0_faulty_gate25_z0)),
#                 r_1_faulty_gate8_z0),
#             Xor(Xor(Xor(Xor(False, r_0_faulty_gate13_z1),
#                         r_0_faulty_gate14_z1),
#                     Xor(Xor(Xor(False, r_0_faulty_gate26_z1),
#                             r_0_faulty_gate27_z1),
#                         r_0_faulty_gate28_z1)),
#                 r_0_faulty_gate29_z0)),
#         r_1_faulty_gate9_z0) ==
#     Not((((((((((r_0_faulty_gate8_z1 ==
#                  ((r_0_faulty_gate16_z1 ==
#                    r_0_faulty_gate17_z1) ==
#                   r_0_faulty_gate18_z1)) ==
#                 r_0_faulty_gate19_z0) ==
#                r_0_faulty_gate24_z0) ==
#               r_1_faulty_gate6_z1) ==
#              (r_1_faulty_gate12_z1 == r_1_faulty_gate13_z1)) ==
#             r_1_faulty_gate14_z0) ==
#            r_1_faulty_gate18_z0) ==
#           (((((((((r_0_faulty_gate5_z1 ==
#                    r_0_faulty_gate10_z1) ==
#                   ((((r_0_faulty_gate16_z1 ==
#                       r_0_faulty_gate17_z1) ==
#                      r_0_faulty_gate18_z1) ==
#                     r_0_faulty_gate19_z1) ==
#                    r_0_faulty_gate20_z1)) ==
#                  r_0_faulty_gate21_z0) ==
#                 r_0_faulty_gate26_z0) ==
#                r_1_faulty_gate4_z1) ==
#               r_1_faulty_gate7_z1) ==
#              ((r_1_faulty_gate12_z1 == r_1_faulty_gate13_z1) ==
#               r_1_faulty_gate14_z1)) ==
#             r_1_faulty_gate15_z0) ==
#            r_1_faulty_gate20_z0)) ==
#          (((((r_0_faulty_gate11_z1 == r_0_faulty_gate24_z1) ==
#              r_0_faulty_gate25_z0) ==
#             r_1_faulty_gate8_z1) ==
#            r_1_faulty_gate18_z1) ==
#           r_1_faulty_gate19_z0)) ==
#         (((r_1_faulty_gate20_z1 == r_1_faulty_gate21_z1) ==
#           (((((r_0_faulty_gate13_z1 == r_0_faulty_gate14_z1) ==
#               ((r_0_faulty_gate26_z1 == r_0_faulty_gate27_z1) ==
#                r_0_faulty_gate28_z1)) ==
#              r_0_faulty_gate29_z0) ==
#             r_1_faulty_gate9_z1) ==
#            r_1_faulty_gate10_z1)) ==
#          r_1_faulty_gate22_z0)),
#     Xor(Xor(Xor(Xor(False,
#                     Xor(Xor(Xor(Xor(Xor(False,
#                                         r_0_faulty_gate13_z1),
#                                     r_0_faulty_gate14_z1),
#                                 Xor(Xor(Xor(False,
#                                         r_0_faulty_gate26_z1),
#                                         r_0_faulty_gate27_z1),
#                                     r_0_faulty_gate28_z1)),
#                             r_0_faulty_gate29_z0),
#                         r_1_faulty_gate9_z1)),
#                 r_1_faulty_gate10_z0),
#             Xor(Xor(Xor(False, r_0_faulty_gate15_z1),
#                     Xor(Xor(Xor(Xor(Xor(False,
#                                         r_0_faulty_gate26_z1),
#                                     r_0_faulty_gate27_z1),
#                                 r_0_faulty_gate28_z1),
#                             r_0_faulty_gate29_z1),
#                         r_0_faulty_gate30_z1)),
#                 r_0_faulty_gate31_z0)),
#         r_1_faulty_gate11_z0) ==
#     ((((r_1_faulty_gate20_z1 == r_1_faulty_gate21_z1) ==
#        (((((r_0_faulty_gate13_z1 == r_0_faulty_gate14_z1) ==
#            ((r_0_faulty_gate26_z1 == r_0_faulty_gate27_z1) ==
#             r_0_faulty_gate28_z1)) ==
#           r_0_faulty_gate29_z0) ==
#          r_1_faulty_gate9_z1) ==
#         r_1_faulty_gate10_z1)) ==
#       r_1_faulty_gate22_z0) ==
#      (((((r_0_faulty_gate15_z1 ==
#           ((((r_0_faulty_gate26_z1 == r_0_faulty_gate27_z1) ==
#              r_0_faulty_gate28_z1) ==
#             r_0_faulty_gate29_z1) ==
#            r_0_faulty_gate30_z1)) ==
#          r_0_faulty_gate31_z0) ==
#         r_1_faulty_gate11_z1) ==
# ...
#
# 0. Fault variables (count = 56):
#    f[0]: Or(Or(r_0_faulty_gate0_x0, r_0_faulty_gate0_z0),
#    Or(r_0_faulty_gate0_x1, r_0_faulty_gate0_z1))
#    f[1]: Or(Or(r_0_faulty_gate1_x0, r_0_faulty_gate1_z0),
#    Or(r_0_faulty_gate1_x1, r_0_faulty_gate1_z1))
#    f[2]: Or(Or(r_0_faulty_gate2_x0, r_0_faulty_gate2_z0),
#    Or(r_0_faulty_gate2_x1, r_0_faulty_gate2_z1))
#    f[3]: Or(Or(r_0_faulty_gate3_x0, r_0_faulty_gate3_z0),
#    Or(r_0_faulty_gate3_x1, r_0_faulty_gate3_z1))
#    f[4]: Or(Or(r_0_faulty_gate4_x0, r_0_faulty_gate4_z0),
#    Or(r_0_faulty_gate4_x1, r_0_faulty_gate4_z1))
#    f[5]: Or(Or(r_0_faulty_gate5_x0, r_0_faulty_gate5_z0),
#    Or(r_0_faulty_gate5_x1, r_0_faulty_gate5_z1))
#    f[6]: Or(Or(r_0_faulty_gate6_x0, r_0_faulty_gate6_z0),
#    Or(r_0_faulty_gate6_x1, r_0_faulty_gate6_z1))
#    f[7]: Or(Or(r_0_faulty_gate7_x0, r_0_faulty_gate7_z0),
#    Or(r_0_faulty_gate7_x1, r_0_faulty_gate7_z1))
#    f[8]: Or(Or(r_0_faulty_gate8_x0, r_0_faulty_gate8_z0),
#    Or(r_0_faulty_gate8_x1, r_0_faulty_gate8_z1))
#    f[9]: Or(Or(r_0_faulty_gate9_x0, r_0_faulty_gate9_z0),
#    Or(r_0_faulty_gate9_x1, r_0_faulty_gate9_z1))
#    f[10]: Or(Or(r_0_faulty_gate10_x0, r_0_faulty_gate10_z0),
#    Or(r_0_faulty_gate10_x1, r_0_faulty_gate10_z1))
#    f[11]: Or(Or(r_0_faulty_gate11_x0, r_0_faulty_gate11_z0),
#    Or(r_0_faulty_gate11_x1, r_0_faulty_gate11_z1))
#    f[12]: Or(Or(r_0_faulty_gate12_x0, r_0_faulty_gate12_z0),
#    Or(r_0_faulty_gate12_x1, r_0_faulty_gate12_z1))
#    f[13]: Or(Or(r_0_faulty_gate13_x0, r_0_faulty_gate13_z0),
#    Or(r_0_faulty_gate13_x1, r_0_faulty_gate13_z1))
#    f[14]: Or(Or(r_0_faulty_gate14_x0, r_0_faulty_gate14_z0),
#    Or(r_0_faulty_gate14_x1, r_0_faulty_gate14_z1))
#    f[15]: Or(Or(r_0_faulty_gate15_x0, r_0_faulty_gate15_z0),
#    Or(r_0_faulty_gate15_x1, r_0_faulty_gate15_z1))
#    f[16]: Or(Or(r_0_faulty_gate16_x0, r_0_faulty_gate16_z0),
#    Or(r_0_faulty_gate16_x1, r_0_faulty_gate16_z1))
#    f[17]: Or(Or(r_0_faulty_gate17_x0, r_0_faulty_gate17_z0),
#    Or(r_0_faulty_gate17_x1, r_0_faulty_gate17_z1))
#    f[18]: Or(Or(r_0_faulty_gate18_x0, r_0_faulty_gate18_z0),
#    Or(r_0_faulty_gate18_x1, r_0_faulty_gate18_z1))
#    f[19]: Or(Or(r_0_faulty_gate19_x0, r_0_faulty_gate19_z0),
#    Or(r_0_faulty_gate19_x1, r_0_faulty_gate19_z1))
#    f[20]: Or(Or(r_0_faulty_gate20_x0, r_0_faulty_gate20_z0),
#    Or(r_0_faulty_gate20_x1, r_0_faulty_gate20_z1))
#    f[21]: Or(Or(r_0_faulty_gate21_x0, r_0_faulty_gate21_z0),
#    Or(r_0_faulty_gate21_x1, r_0_faulty_gate21_z1))
#    f[22]: Or(Or(r_0_faulty_gate22_x0, r_0_faulty_gate22_z0),
#    Or(r_0_faulty_gate22_x1, r_0_faulty_gate22_z1))
#    f[23]: Or(Or(r_0_faulty_gate23_x0, r_0_faulty_gate23_z0),
#    Or(r_0_faulty_gate23_x1, r_0_faulty_gate23_z1))
#    f[24]: Or(Or(r_0_faulty_gate24_x0, r_0_faulty_gate24_z0),
#    Or(r_0_faulty_gate24_x1, r_0_faulty_gate24_z1))
#    f[25]: Or(Or(r_0_faulty_gate25_x0, r_0_faulty_gate25_z0),
#    Or(r_0_faulty_gate25_x1, r_0_faulty_gate25_z1))
#    f[26]: Or(Or(r_0_faulty_gate26_x0, r_0_faulty_gate26_z0),
#    Or(r_0_faulty_gate26_x1, r_0_faulty_gate26_z1))
#    f[27]: Or(Or(r_0_faulty_gate27_x0, r_0_faulty_gate27_z0),
#    Or(r_0_faulty_gate27_x1, r_0_faulty_gate27_z1))
#    f[28]: Or(Or(r_0_faulty_gate28_x0, r_0_faulty_gate28_z0),
#    Or(r_0_faulty_gate28_x1, r_0_faulty_gate28_z1))
#    f[29]: Or(Or(r_0_faulty_gate29_x0, r_0_faulty_gate29_z0),
#    Or(r_0_faulty_gate29_x1, r_0_faulty_gate29_z1))
#    f[30]: Or(Or(r_0_faulty_gate30_x0, r_0_faulty_gate30_z0),
#    Or(r_0_faulty_gate30_x1, r_0_faulty_gate30_z1))
#    f[31]: Or(Or(r_0_faulty_gate31_x0, r_0_faulty_gate31_z0),
#    Or(r_0_faulty_gate31_x1, r_0_faulty_gate31_z1))
#    f[32]: Or(Or(r_1_faulty_gate0_x0, r_1_faulty_gate0_z0),
#    Or(r_1_faulty_gate0_x1, r_1_faulty_gate0_z1))
#    f[33]: Or(Or(r_1_faulty_gate1_x0, r_1_faulty_gate1_z0),
#    Or(r_1_faulty_gate1_x1, r_1_faulty_gate1_z1))
#    f[34]: Or(Or(r_1_faulty_gate2_x0, r_1_faulty_gate2_z0),
#    Or(r_1_faulty_gate2_x1, r_1_faulty_gate2_z1))
#    f[35]: Or(Or(r_1_faulty_gate3_x0, r_1_faulty_gate3_z0),
#    Or(r_1_faulty_gate3_x1, r_1_faulty_gate3_z1))
#    f[36]: Or(Or(r_1_faulty_gate4_x0, r_1_faulty_gate4_z0),
#    Or(r_1_faulty_gate4_x1, r_1_faulty_gate4_z1))
#    f[37]: Or(Or(r_1_faulty_gate5_x0, r_1_faulty_gate5_z0),
#    Or(r_1_faulty_gate5_x1, r_1_faulty_gate5_z1))
#    f[38]: Or(Or(r_1_faulty_gate6_x0, r_1_faulty_gate6_z0),
#    Or(r_1_faulty_gate6_x1, r_1_faulty_gate6_z1))
#    f[39]: Or(Or(r_1_faulty_gate7_x0, r_1_faulty_gate7_z0),
#    Or(r_1_faulty_gate7_x1, r_1_faulty_gate7_z1))
#    f[40]: Or(Or(r_1_faulty_gate8_x0, r_1_faulty_gate8_z0),
#    Or(r_1_faulty_gate8_x1, r_1_faulty_gate8_z1))
#    f[41]: Or(Or(r_1_faulty_gate9_x0, r_1_faulty_gate9_z0),
#    Or(r_1_faulty_gate9_x1, r_1_faulty_gate9_z1))
#    f[42]: Or(Or(r_1_faulty_gate10_x0, r_1_faulty_gate10_z0),
#    Or(r_1_faulty_gate10_x1, r_1_faulty_gate10_z1))
#    f[43]: Or(Or(r_1_faulty_gate11_x0, r_1_faulty_gate11_z0),
#    Or(r_1_faulty_gate11_x1, r_1_faulty_gate11_z1))
#    f[44]: Or(Or(r_1_faulty_gate12_x0, r_1_faulty_gate12_z0),
#    Or(r_1_faulty_gate12_x1, r_1_faulty_gate12_z1))
#    f[45]: Or(Or(r_1_faulty_gate13_x0, r_1_faulty_gate13_z0),
#    Or(r_1_faulty_gate13_x1, r_1_faulty_gate13_z1))
#    f[46]: Or(Or(r_1_faulty_gate14_x0, r_1_faulty_gate14_z0),
#    Or(r_1_faulty_gate14_x1, r_1_faulty_gate14_z1))
#    f[47]: Or(Or(r_1_faulty_gate15_x0, r_1_faulty_gate15_z0),
#    Or(r_1_faulty_gate15_x1, r_1_faulty_gate15_z1))
#    f[48]: Or(Or(r_1_faulty_gate16_x0, r_1_faulty_gate16_z0),
#    Or(r_1_faulty_gate16_x1, r_1_faulty_gate16_z1))
#    f[49]: Or(Or(r_1_faulty_gate17_x0, r_1_faulty_gate17_z0),
#    Or(r_1_faulty_gate17_x1, r_1_faulty_gate17_z1))
#    f[50]: Or(Or(r_1_faulty_gate18_x0, r_1_faulty_gate18_z0),
#    Or(r_1_faulty_gate18_x1, r_1_faulty_gate18_z1))
#    f[51]: Or(Or(r_1_faulty_gate19_x0, r_1_faulty_gate19_z0),
#    Or(r_1_faulty_gate19_x1, r_1_faulty_gate19_z1))
#    f[52]: Or(Or(r_1_faulty_gate20_x0, r_1_faulty_gate20_z0),
#    Or(r_1_faulty_gate20_x1, r_1_faulty_gate20_z1))
#    f[53]: Or(Or(r_1_faulty_gate21_x0, r_1_faulty_gate21_z0),
#    Or(r_1_faulty_gate21_x1, r_1_faulty_gate21_z1))
#    f[54]: Or(Or(r_1_faulty_gate22_x0, r_1_faulty_gate22_z0),
#    Or(r_1_faulty_gate22_x1, r_1_faulty_gate22_z1))
#    f[55]: Or(Or(r_1_faulty_gate23_x0, r_1_faulty_gate23_z0),
#    Or(r_1_faulty_gate23_x1, r_1_faulty_gate23_z1))
#
#    At-most-1-faults constraint (PbEq):
#    PbEq(((Or(Or(r_0_faulty_gate0_x0, r_0_faulty_gate0_z0),
#           Or(r_0_faulty_gate0_x1, r_0_faulty_gate0_z1)),
#        1),
#       (Or(Or(r_0_faulty_gate1_x0, r_0_faulty_gate1_z0),
#           Or(r_0_faulty_gate1_x1, r_0_faulty_gate1_z1)),
#        1),
#       (Or(Or(r_0_faulty_gate2_x0, r_0_faulty_gate2_z0),
#           Or(r_0_faulty_gate2_x1, r_0_faulty_gate2_z1)),
#        1),
#       (Or(Or(r_0_faulty_gate3_x0, r_0_faulty_gate3_z0),
#           Or(r_0_faulty_gate3_x1, r_0_faulty_gate3_z1)),
#        1),
#       (Or(Or(r_0_faulty_gate4_x0, r_0_faulty_gate4_z0),
#           Or(r_0_faulty_gate4_x1, r_0_faulty_gate4_z1)),
#        1),
#       (Or(Or(r_0_faulty_gate5_x0, r_0_faulty_gate5_z0),
#           Or(r_0_faulty_gate5_x1, r_0_faulty_gate5_z1)),
#        1),
#       (Or(Or(r_0_faulty_gate6_x0, r_0_faulty_gate6_z0),
#           Or(r_0_faulty_gate6_x1, r_0_faulty_gate6_z1)),
#        1),
#       (Or(Or(r_0_faulty_gate7_x0, r_0_faulty_gate7_z0),
#           Or(r_0_faulty_gate7_x1, r_0_faulty_gate7_z1)),
#        1),
#       (Or(Or(r_0_faulty_gate8_x0, r_0_faulty_gate8_z0),
#           Or(r_0_faulty_gate8_x1, r_0_faulty_gate8_z1)),
#        1),
#       (Or(Or(r_0_faulty_gate9_x0, r_0_faulty_gate9_z0),
#           Or(r_0_faulty_gate9_x1, r_0_faulty_gate9_z1)),
#        1),
#       (Or(Or(r_0_faulty_gate10_x0, r_0_faulty_gate10_z0),
#           Or(r_0_faulty_gate10_x1, r_0_faulty_gate10_z1)),
#        1),
#       (Or(Or(r_0_faulty_gate11_x0, r_0_faulty_gate11_z0),
#           Or(r_0_faulty_gate11_x1, r_0_faulty_gate11_z1)),
#        1),
#       (Or(Or(r_0_faulty_gate12_x0, r_0_faulty_gate12_z0),
#           Or(r_0_faulty_gate12_x1, r_0_faulty_gate12_z1)),
#        1),
#       (Or(Or(r_0_faulty_gate13_x0, r_0_faulty_gate13_z0),
#           Or(r_0_faulty_gate13_x1, r_0_faulty_gate13_z1)),
#        1),
#       (Or(Or(r_0_faulty_gate14_x0, r_0_faulty_gate14_z0),
#           Or(r_0_faulty_gate14_x1, r_0_faulty_gate14_z1)),
#        1),
#       (Or(Or(r_0_faulty_gate15_x0, r_0_faulty_gate15_z0),
#           Or(r_0_faulty_gate15_x1, r_0_faulty_gate15_z1)),
#        1),
#       (Or(Or(r_0_faulty_gate16_x0, r_0_faulty_gate16_z0),
#           Or(r_0_faulty_gate16_x1, r_0_faulty_gate16_z1)),
#        1),
#       (Or(Or(r_0_faulty_gate17_x0, r_0_faulty_gate17_z0),
#           Or(r_0_faulty_gate17_x1, r_0_faulty_gate17_z1)),
#        1),
#       (Or(Or(r_0_faulty_gate18_x0, r_0_faulty_gate18_z0),
#           Or(r_0_faulty_gate18_x1, r_0_faulty_gate18_z1)),
#        1),
#       (Or(Or(r_0_faulty_gate19_x0, r_0_faulty_gate19_z0),
#           Or(r_0_faulty_gate19_x1, r_0_faulty_gate19_z1)),
#        1),
#       (Or(Or(r_0_faulty_gate20_x0, r_0_faulty_gate20_z0),
#           Or(r_0_faulty_gate20_x1, r_0_faulty_gate20_z1)),
#        1),
#       (Or(Or(r_0_faulty_gate21_x0, r_0_faulty_gate21_z0),
#           Or(r_0_faulty_gate21_x1, r_0_faulty_gate21_z1)),
#        1),
#       (Or(Or(r_0_faulty_gate22_x0, r_0_faulty_gate22_z0),
#           Or(r_0_faulty_gate22_x1, r_0_faulty_gate22_z1)),
#        1),
#       (Or(Or(r_0_faulty_gate23_x0, r_0_faulty_gate23_z0),
#           Or(r_0_faulty_gate23_x1, r_0_faulty_gate23_z1)),
#        1),
#       (Or(Or(r_0_faulty_gate24_x0, r_0_faulty_gate24_z0),
#           Or(r_0_faulty_gate24_x1, r_0_faulty_gate24_z1)),
#        1),
#       (Or(Or(r_0_faulty_gate25_x0, r_0_faulty_gate25_z0),
#           Or(r_0_faulty_gate25_x1, r_0_faulty_gate25_z1)),
#        1),
#       (Or(Or(r_0_faulty_gate26_x0, r_0_faulty_gate26_z0),
#           Or(r_0_faulty_gate26_x1, r_0_faulty_gate26_z1)),
#        1),
#       (Or(Or(r_0_faulty_gate27_x0, r_0_faulty_gate27_z0),
#           Or(r_0_faulty_gate27_x1, r_0_faulty_gate27_z1)),
#        1),
#       (Or(Or(r_0_faulty_gate28_x0, r_0_faulty_gate28_z0),
#           Or(r_0_faulty_gate28_x1, r_0_faulty_gate28_z1)),
#        1),
#       (Or(Or(r_0_faulty_gate29_x0, r_0_faulty_gate29_z0),
# ...
#                                     r_0_faulty_gate4_z0),
#                                 False),
#                             r_0_faulty_gate5_z0),
#                         Xor(False, r_0_faulty_gate3_z1)),
#                     r_0_faulty_gate6_z0),
#                 False),
#             r_0_faulty_gate7_z0),
#         Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(False,
#                                         Xor(Xor(Xor(Xor(Xor(False,
#                                         r_0_faulty_gate8_z1),
#                                         Xor(Xor(..., ...),
#                                         r_0_faulty_gate18_z1)),
#                                         r_0_faulty_gate19_z0),
#                                         False),
#                                         r_0_faulty_gate24_z0)),
#                                         r_1_faulty_gate8_z0),
#                                         False),
#                                         r_1_faulty_gate9_z0),
#                                         Xor(Xor(Xor(Xor(Xor(Xor(Xor(False,
#                                         r_0_faulty_gate5_z1),
#                                         r_0_faulty_gate10_z1),
#                                         Xor(Xor(Xor(Xor(Xor(...,
#                                         ...),
#                                         r_0_faulty_gate17_z1),
#                                         r_0_faulty_gate18_z1),
#                                         r_0_faulty_gate19_z1),
#                                         r_0_faulty_gate20_z1)),
#                                         r_0_faulty_gate21_z0),
#                                         False),
#                                         r_0_faulty_gate26_z0),
#                                         r_1_faulty_gate5_z1)),
#                                     r_1_faulty_gate10_z0),
#                                 Xor(Xor(Xor(False,
#                                         r_0_faulty_gate11_z1),
#                                         Xor(False,
#                                         r_0_faulty_gate24_z1)),
#                                     r_0_faulty_gate25_z0)),
#                             r_1_faulty_gate11_z0),
#                         Xor(False, r_1_faulty_gate9_z1)),
#                     r_1_faulty_gate12_z0),
#                 Xor(Xor(Xor(Xor(False, r_0_faulty_gate13_z1),
#                             r_0_faulty_gate14_z1),
#                         Xor(Xor(Xor(False,
#                                     r_0_faulty_gate26_z1),
#                                 r_0_faulty_gate27_z1),
#                             r_0_faulty_gate28_z1)),
#                     r_0_faulty_gate29_z0)),
#             r_1_faulty_gate13_z0) ==
#         Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(False,
#                                         False),
#                                         r_0_faulty_gate8_z0),
#                                         False),
#                                         r_0_faulty_gate9_z0),
#                                         Xor(False,
#                                         r_0_faulty_gate5_z1)),
#                                     r_0_faulty_gate10_z0),
#                                 False),
#                             r_0_faulty_gate11_z0),
#                         Xor(False, r_0_faulty_gate9_z1)),
#                     r_0_faulty_gate12_z0),
#                 False),
#             r_0_faulty_gate13_z0),
#         Xor(Xor(Xor(Xor(False,
#                         Xor(Xor(Xor(Xor(Xor(False,
#                                         r_0_faulty_gate13_z1),
#                                         r_0_faulty_gate14_z1),
#                                     Xor(Xor(Xor(False,
#                                         r_0_faulty_gate26_z1),
#                                         r_0_faulty_gate27_z1),
#                                         r_0_faulty_gate28_z1)),
#                                 r_0_faulty_gate29_z0),
#                             r_1_faulty_gate13_z1)),
#                     r_1_faulty_gate14_z0),
#                 Xor(Xor(Xor(False, r_0_faulty_gate15_z1),
#                         Xor(Xor(Xor(Xor(Xor(False,
#                                         r_0_faulty_gate26_z1),
#                                         r_0_faulty_gate27_z1),
#                                     r_0_faulty_gate28_z1),
#                                 r_0_faulty_gate29_z1),
#                             r_0_faulty_gate30_z1)),
#                     r_0_faulty_gate31_z0)),
#             r_1_faulty_gate15_z0) ==
#         Xor(Xor(Xor(Xor(False,
#                         Xor(False, r_0_faulty_gate13_z1)),
#                     r_0_faulty_gate14_z0),
#                 False),
#             r_0_faulty_gate15_z0),
#         Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(False,
#                                         Xor(Xor(Xor(Xor(Xor(False,
#                                         False),
#                                         r_0_faulty_gate0_x1),
#                                         r_0_faulty_gate16_x0),
#                                         False),
#                                         r_1_faulty_gate0_x1)),
#                                         r_1_faulty_gate16_x1),
#                                         False),
#                                         r_1_faulty_gate17_x1),
#                                         Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(False,
#                                         Xor(..., ...)),
#                                         r_0_faulty_gate1_x1),
#                                         False),
# ...
#    Condition 2: True
#    Condition 3: And(Xor(Xor(Xor(Xor(False,
#                     Xor(Xor(Xor(Xor(Xor(Xor(False,
#                                         r_0_faulty_gate0_z1),
#                                         False),
#                                     r_0_faulty_gate16_z0),
#                                 r_1_faulty_gate0_z1),
#                             False),
#                         r_1_faulty_gate16_z0)),
#                 r_2_faulty_gate0_z0),
#             Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(False,
#                                         r_0_faulty_gate1_z1),
#                                         r_0_faulty_gate2_z1),
#                                     Xor(Xor(False,
#                                         r_0_faulty_gate16_z1),
#                                         r_0_faulty_gate17_z1)),
#                                 r_0_faulty_gate18_z0),
#                             r_1_faulty_gate1_z1),
#                         r_1_faulty_gate2_z1),
#                     Xor(Xor(False, r_1_faulty_gate16_z1),
#                         r_1_faulty_gate17_z1)),
#                 r_1_faulty_gate18_z0)),
#         r_2_faulty_gate1_z0) ==
#     Not((((((((((((r_0_faulty_gate16_z1 ==
#                    r_0_faulty_gate17_z1) ==
#                   (r_0_faulty_gate1_z1 ==
#                    r_0_faulty_gate2_z1)) ==
#                  r_0_faulty_gate18_z0) ==
#                 r_1_faulty_gate1_z1) ==
#                r_1_faulty_gate2_z1) ==
#               (r_1_faulty_gate16_z1 == r_1_faulty_gate17_z1)) ==
#              r_1_faulty_gate18_z0) ==
#             r_2_faulty_gate1_z1) ==
#            r_2_faulty_gate2_z1) ==
#           r_2_faulty_gate12_z1) ==
#          r_2_faulty_gate13_z0) ==
#         (((((r_0_faulty_gate0_z1 == r_0_faulty_gate16_z0) ==
#             r_1_faulty_gate0_z1) ==
#            r_1_faulty_gate16_z0) ==
#           r_2_faulty_gate0_z1) ==
#          r_2_faulty_gate12_z0)),
#     Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(False,
#                                     Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(False,
#                                         r_0_faulty_gate1_z1),
#                                         r_0_faulty_gate2_z1),
#                                         Xor(Xor(False,
#                                         r_0_faulty_gate16_z1),
#                                         r_0_faulty_gate17_z1)),
#                                         r_0_faulty_gate18_z0),
#                                         r_1_faulty_gate1_z1),
#                                         r_1_faulty_gate2_z1),
#                                         Xor(Xor(False,
#                                         r_1_faulty_gate16_z1),
#                                         r_1_faulty_gate17_z1)),
#                                         r_1_faulty_gate18_z0),
#                                         r_2_faulty_gate1_z1)),
#                                 r_2_faulty_gate2_z0),
#                             Xor(Xor(Xor(Xor(Xor(Xor(False,
#                                         r_0_faulty_gate4_z1),
#                                         False),
#                                         r_0_faulty_gate22_z0),
#                                         r_1_faulty_gate4_z1),
#                                     False),
#                                 r_1_faulty_gate22_z0)),
#                         r_2_faulty_gate3_z0),
#                     Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(False,
#                                         r_0_faulty_gate5_z1),
#                                         r_0_faulty_gate10_z1),
#                                         Xor(Xor(Xor(Xor(Xor(...,
#                                         ...),
#                                         r_0_faulty_gate17_z1),
#                                         r_0_faulty_gate18_z1),
#                                         r_0_faulty_gate19_z1),
#                                         r_0_faulty_gate20_z1)),
#                                         r_0_faulty_gate21_z0),
#                                         False),
#                                         r_0_faulty_gate26_z0),
#                                         r_1_faulty_gate5_z1),
#                                         r_1_faulty_gate10_z1),
#                                     Xor(Xor(Xor(Xor(Xor(False,
#                                         r_1_faulty_gate16_z1),
#                                         r_1_faulty_gate17_z1),
#                                         r_1_faulty_gate18_z1),
#                                         r_1_faulty_gate19_z1),
#                                         r_1_faulty_gate20_z1)),
#                                 r_1_faulty_gate21_z0),
#                             False),
#                         r_1_faulty_gate26_z0)),
#                 r_2_faulty_gate4_z0),
#             Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(False,
#                                         r_0_faulty_gate7_z1),
#                                         Xor(False,
#                                         r_0_faulty_gate22_z1)),
#                                         r_0_faulty_gate23_z0),
#                                         Xor(Xor(False,
#                                         r_0_faulty_gate26_z1),
#                                         r_0_faulty_gate27_z1)),
#                                     r_0_faulty_gate28_z0),
#                                 r_1_faulty_gate7_z1),
#                             Xor(False, r_1_faulty_gate22_z1)),
#                         r_1_faulty_gate23_z0),
#                     Xor(Xor(False, r_1_faulty_gate26_z1),
#                         r_1_faulty_gate27_z1)),
#                 r_1_faulty_gate28_z0)),
#         r_2_faulty_gate5_z0) ==
#     Not((((((((r_0_faulty_gate4_z1 == r_0_faulty_gate22_z0) ==
#               r_1_faulty_gate4_z1) ==
#              r_1_faulty_gate22_z0) ==
#             r_2_faulty_gate3_z1) ==
#            r_2_faulty_gate16_z0) ==
#           (((((((((((r_0_faulty_gate16_z1 ==
#                      r_0_faulty_gate17_z1) ==
#                     (r_0_faulty_gate1_z1 ==
#                      r_0_faulty_gate2_z1)) ==
#                    r_0_faulty_gate18_z0) ==
#                   r_1_faulty_gate1_z1) ==
#                  r_1_faulty_gate2_z1) ==
#                 (r_1_faulty_gate16_z1 ==
#                  r_1_faulty_gate17_z1)) ==
#                r_1_faulty_gate18_z0) ==
#               r_2_faulty_gate1_z1) ==
#              r_2_faulty_gate2_z1) ==
#             r_2_faulty_gate12_z1) ==
#            r_2_faulty_gate13_z0)) ==
#          ((((((((((((((r_0_faulty_gate5_z1 ==
#                        r_0_faulty_gate10_z1) ==
#                       ((((...) == ...) ==
#                         r_0_faulty_gate19_z1) ==
#                        r_0_faulty_gate20_z1)) ==
#                      r_0_faulty_gate21_z0) ==
#                     r_0_faulty_gate26_z0) ==
#                    r_1_faulty_gate5_z1) ==
#                   r_1_faulty_gate10_z1) ==
#                  ((((r_1_faulty_gate16_z1 ==
#                      r_1_faulty_gate17_z1) ==
#                     r_1_faulty_gate18_z1) ==
#                    r_1_faulty_gate19_z1) ==
#                   r_1_faulty_gate20_z1)) ==
#                 r_1_faulty_gate21_z0) ==
#                r_1_faulty_gate26_z0) ==
#               r_2_faulty_gate4_z1) ==
#              r_2_faulty_gate7_z1) ==
#             ((r_2_faulty_gate12_z1 == r_2_faulty_gate13_z1) ==
#              r_2_faulty_gate14_z1)) ==
#            r_2_faulty_gate15_z0) ==
#           r_2_faulty_gate20_z0)) ==
#         ((((((((((((((r_0_faulty_gate7_z1 ==
#                       r_0_faulty_gate22_z1) ==
#                      r_0_faulty_gate23_z0) ==
#                     (r_0_faulty_gate26_z1 ==
#                      r_0_faulty_gate27_z1)) ==
#                    r_0_faulty_gate28_z0) ==
#                   r_1_faulty_gate7_z1) ==
#                  r_1_faulty_gate22_z1) ==
#                 r_1_faulty_gate23_z0) ==
#                (r_1_faulty_gate26_z1 == r_1_faulty_gate27_z1)) ==
#               r_1_faulty_gate28_z0) ==
#              r_2_faulty_gate5_z1) ==
#             r_2_faulty_gate16_z1) ==
#            r_2_faulty_gate17_z0) ==
#           r_2_faulty_gate20_z1) ==
#          r_2_faulty_gate21_z0)),
#     Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(False,
#                                     Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(False,
#                                         r_0_faulty_gate8_z1),
#                                         Xor(Xor(..., ...),
#                                         r_0_faulty_gate18_z1)),
#                                         r_0_faulty_gate19_z0),
#                                         False),
#                                         r_0_faulty_gate24_z0),
#                                         r_1_faulty_gate8_z1),
#                                         Xor(Xor(Xor(False,
#                                         r_1_faulty_gate16_z1),
#                                         r_1_faulty_gate17_z1),
#                                         r_1_faulty_gate18_z1)),
#                                         r_1_faulty_gate19_z0),
#                                         False),
#                                         r_1_faulty_gate24_z0)),
#                                 r_2_faulty_gate6_z0),
#                             Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(Xor(...,
#                                         ...),
#                                         r_0_faulty_gate10_z1),
#                                         Xor(Xor(..., ...),
#                                         r_0_faulty_gate20_z1)),
#                                         r_0_faulty_gate21_z0),
#                                         False),
#                                         r_0_faulty_gate26_z0),
#                                         r_1_faulty_gate5_z1),
#                                         r_1_faulty_gate10_z1),
#                                         Xor(Xor(Xor(Xor(Xor(False,
#                                         r_1_faulty_gate16_z1),
#                                         r_1_faulty_gate17_z1),
#                                         r_1_faulty_gate18_z1),
#                                         r_1_faulty_gate19_z1),
#                                         r_1_faulty_gate20_z1)),
#                                         r_1_faulty_gate21_z0),
#                                         False),
#                                     r_1_faulty_gate26_z0),
#                                 r_2_faulty_gate4_z1)),
#                         r_2_faulty_gate7_z0),
#                     Xor(Xor(Xor(Xor(Xor(Xor(False,
# ...
#
# ================================================================================
